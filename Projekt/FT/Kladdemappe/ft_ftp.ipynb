# %% [markdown]
# # Nødvendige biblioteker

# %%
import requests
import ftplib
import pandas as pd
import numpy as np
import tqdm
import time
from io import BytesIO
from bs4 import BeautifulSoup as bs

# %% [markdown]
# # Opsætning af ftp serveradresse og bibliotek

# %%
ftp_url = "oda.ft.dk"
ftp_dir = "/ODAXML/Referat/samling/"

# %% [markdown]
# # Initialisering af lister
# ## Jeg skal finde ud af, hvordan jeg dropper dem igen, når jeg er færdig

# %%
dirs = []
sub_dir = []
filer = []
filer_navne = []
filer_size = []
sti_navn = []
indhold = []
suppe = []

# %% [markdown]
# # Login til ftp serveren og henter en liste over biblioteker

# %%
ftp = ftplib.FTP(ftp_url)
ftp.login("anonymous", "wpg345@alumni.ku.dk")
ftp.set_pasv(True)
ftp.cwd(ftp_dir)
ftp.dir(dirs.append)

# %% [markdown]
# # Bygger en liste med underbibliotekter

# %%
for i in range (0, len(dirs), 1):
    sub_dir.append(ftp_dir+dirs[i][-5:]+'/')

# %% [markdown]
# # Bygger en liste med filnavne

# %%
for i in range (0, len(sub_dir), 1):
    ftp.cwd(sub_dir[i])
    ftp.dir(filer.append)

# %% [markdown]
# # Ekstrakt af filnavn

# %%
for i in range(0, len(filer)):
    filer_navne.append(filer[i][39:])

# %% [markdown]
# # Opbygning af hele stien og filnavn

# %%
for i in range(0, len(filer_navne)):
    sti_navn.append(ftp_dir+filer_navne[i][0:5]+'/'+filer_navne[i])

# %% [markdown]
# # Overførsel af de enkelte filer fra ftp://oda.ft.dk, og indholdet skrives til liste

# %%
for i in tqdm.tqdm(range(0, len(sti_navn))):
# for i in tqdm.tqdm(range(0, 10)):
    r = BytesIO()
    ftp.retrbinary(f"RETR {sti_navn[i]}", r.write)
    indhold.append(r.getvalue())
    r.close()
# Out:
# 100%|██████████| 1489/1489 [03:01<00:00,  8.19it/s]

# %%
indhold[0]
# Out:
# b'\xef\xbb\xbf<?xml version="1.0" encoding="utf-8"?><Dokument edixistatus=""><MetaMeeting><ParliamentarySession>20091</ParliamentarySession><ParliamentaryGroup>Folketinget</ParliamentaryGroup><MeetingNumber>100</MeetingNumber><DateOfSitting>2010-05-31T10:00:00</DateOfSitting><Location>Folketingssalen</Location><EdixiDocLocation>W:\\20091\\M100\\</EdixiDocLocation><AudioFileFolder>X:\\DAudio\\FT2009\\100\\SALEN\\</AudioFileFolder></MetaMeeting><TitelGruppe><Titel><Linea><Char>100. m\xc3\xb8de</Char></Linea></Titel><UnderTitel><Linea><Char>Mandag den 31. maj 2010 kl. 10.00</Char></Linea></UnderTitel></TitelGruppe><DagsordenPlan><Rubrica>\r\n  <Linea>\r\n    <Char>Dagsorden</Char>\r\n  </Linea>\r\n</Rubrica>\r\n<PunktTekst>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>1) 1. behandling af lovforslag nr. L 222:</Char>\r\n    </Linea>\r\n  </Exitus>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>Forslag til lov om \xc3\xa6ndring af lov om arbejdsl\xc3\xb8shedsforsikring m.v. (Neds\xc3\xa6ttelse af dagpengeperioden).</Char>\r\n    </Linea>\r\n  </Exitus>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>Af besk\xc3\xa6ftigelsesministeren (Inger St\xc3\xb8jberg).</Char>\r\n    </Linea>\r\n  </Exitus>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>(Frems\xc3\xa6ttelse 27.05.2010).</Char>\r\n    </Linea>\r\n  </Exitus>\r\n</PunktTekst>\r\n<PunktTekst>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>2) 1. behandling af lovforslag nr. L 218:</Char>\r\n    </Linea>\r\n  </Exitus>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>Forslag til lov om \xc3\xa6ndring af lov om neds\xc3\xa6ttelse af statstilskuddet til kommuner ved forh\xc3\xb8jelser af den kommunale skatteudskrivning. (\xc3\x86ndring af perioden for individuelle neds\xc3\xa6ttelser af bloktilskuddet og justering af undtagelsesbestemmelserne for kommuner, der tidligere har nedsat skatten).</Char>\r\n    </Linea>\r\n  </Exitus>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>Af indenrigs- og sundhedsministeren (Bertel Haarder).</Char>\r\n    </Linea>\r\n  </Exitus>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>(Frems\xc3\xa6ttelse 26.05.2010).</Char>\r\n    </Linea>\r\n  </Exitus>\r\n</PunktTekst>\r\n<PunktTekst>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>3) 1. behandling af lovforslag nr. L 219:</Char>\r\n    </Linea>\r\n  </Exitus>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>Forslag til lov om \xc3\xa6ndring af lov om kommunal udligning og generelle tilskud til kommuner. (Forh\xc3\xb8jelse af det betingede bloktilskud og neds\xc3\xa6ttelse af bloktilskud ved budgetoverskridelser).</Char>\r\n    </Linea>\r\n  </Exitus>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>Af indenrigs- og sundhedsministeren (Bertel Haarder).</Char>\r\n    </Linea>\r\n  </Exitus>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>(Frems\xc3\xa6ttelse 27.05.2010).</Char>\r\n    </Linea>\r\n  </Exitus>\r\n</PunktTekst>\r\n<PunktTekst>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>4) 1. behandling af lovforslag nr. L 223:</Char>\r\n    </Linea>\r\n  </Exitus>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>Forslag til lov om \xc3\xa6ndring af lov om statens voksenuddannelsesst\xc3\xb8tte (SVU). (Forkortelse af perioden med statens voksenuddannelsesst\xc3\xb8tte til uddannelse p\xc3\xa5 folkeskoleniveau og til gymnasial uddannelse).</Char>\r\n    </Linea>\r\n  </Exitus>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>Af undervisningsministeren (Tina Nedergaard).</Char>\r\n    </Linea>\r\n  </Exitus>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>(Frems\xc3\xa6ttelse 27.05.2010).</Char>\r\n    </Linea>\r\n  </Exitus>\r\n</PunktTekst>\r\n<PunktTekst>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>5) 1. behandling af lovforslag nr. L 221:</Char>\r\n    </Linea>\r\n  </Exitus>\r\n  <Exitus>\r\n    <Linea>\r\n      <Char>Forslag til lov om \xc3\xa6ndring af personskatteloven, ligningsloven og b\xc3\xb8rnefamilieydelsesloven. (Ingen regulering af bel\xc3\xb8bsgr\xc3\xa6nser i 2011-2013, begr\xc3\xa6nsning af fradraget for faglige kontingenter og loft over b\xc3\xb8r ...

# %% [markdown]
# # BeautifulSoup - her kommer der korrekte danske karakterer, og der sker eet eller andet med XML-tags'ene
# ## Men det er tilsyneladende ikke alle æøå, den kan finde ud af

# %%
for i in tqdm.tqdm(range (0,10)):
    suppe.append(bs(indhold[i],"lxml"))
# Out:
# 100%|██████████| 10/10 [00:05<00:00,  1.73it/s]

# %% [markdown]
# # Dataframe skabes

# %%
df_suppe = pd.DataFrame(suppe, columns = ['metadata', 'indhold'])
# Out:
# /Users/dana_tiger/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py:309: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])

# %% [markdown]
# # Der søges på de møder i salen, hvor ordet "sygeplejerske" har været nævnt
# # Der returneres 512 møder i salen, hvilket svarer til ca. 35%

# %%
substring = 'sygeplejerske'
df_sygep = df_suppe[df_suppe.apply(lambda row: row.astype(str).str.contains(substring, case=False).any(), axis=1)]

# %%
df_suppe.to_csv('suppe.csv')

# %%
df_sygep.to_csv('sygep.csv')

# %%
pd.read_csv('suppe.csv')
# Out:
#    Unnamed: 0                             metadata  \
# 0           0  xml version="1.0" encoding="utf-8"?
# 1           1  xml version="1.0" encoding="utf-8"?
# 2           2  xml version="1.0" encoding="utf-8"?
# 3           3  xml version="1.0" encoding="utf-8"?
# 4           4  xml version="1.0" encoding="utf-8"?
# 5           5  xml version="1.0" encoding="utf-8"?
# 6           6  xml version="1.0" encoding="utf-8"?
# 7           7  xml version="1.0" encoding="utf-8"?
# 8           8  xml version="1.0" encoding="utf-8"?
# 9           9  xml version="1.0" encoding="utf-8"?
#
#                                              indhold
# 0  <html><body><dokument edixistatus=""><metameet...
# 1  <html><body><dokument edixistatus=""><metameet...
# 2  <html><body><dokument edixistatus=""><metameet...
# 3  <html><body><dokument edixistatus=""><metameet...
# 4  <html><body><dokument edixistatus=""><metameet...
# 5  <html><body><dokument edixistatus=""><metameet...
# 6  <html><body><dokument edixistatus=""><metameet...
# 7  <html><body><dokument edixistatus=""><metameet...
# 8  <html><body><dokument edixistatus=""><metameet...
# 9  <html><body><dokument edixistatus=""><metameet...

# %%
pd.read_csv('sygep.csv')
# Out:
#    Unnamed: 0                             metadata  \
# 0           0  xml version="1.0" encoding="utf-8"?
# 1           2  xml version="1.0" encoding="utf-8"?
# 2           3  xml version="1.0" encoding="utf-8"?
# 3           6  xml version="1.0" encoding="utf-8"?
# 4           7  xml version="1.0" encoding="utf-8"?
# 5           9  xml version="1.0" encoding="utf-8"?
#
#                                              indhold
# 0  <html><body><dokument edixistatus=""><metameet...
# 1  <html><body><dokument edixistatus=""><metameet...
# 2  <html><body><dokument edixistatus=""><metameet...
# 3  <html><body><dokument edixistatus=""><metameet...
# 4  <html><body><dokument edixistatus=""><metameet...
# 5  <html><body><dokument edixistatus=""><metameet...
