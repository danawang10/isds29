# %% [markdown]
# # Analysis

# %%
# %pip install lemmy
# Out:
# Collecting lemmy
#   Using cached lemmy-2.1.0-py2.py3-none-any.whl (1.1 MB)
# Installing collected packages: lemmy
# Successfully installed lemmy-2.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
import tqdm
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import re
import lemmy # For lemmatization
import nltk
import itertools

# %% [markdown]
# ## Load datasets

# %%
ft_sygeplej2x = pd.read_csv('ft_sygeplej2x.csv')
dr_sygeplej2x = pd.read_csv('dr_sygeplej2x.csv')
tv2_sygeplej2x = pd.read_csv('tv2_sygeplej2x.csv')

ft_2 = ft_sygeplej2x.copy() 
dr_2 = dr_sygeplej2x.copy() 
tv2_2 = tv2_sygeplej2x.copy()

# %% [markdown]
# # Test

# %%
for i in tv2.content:
    tv2_without_stopwords = [word for word in tv2_2_tokens if not word in stopwords]
# Out:
# 'mens nyuddannede, danske sygeplejersker har mere end svært ved at finde arbejde i danmark, er situationen ganske anderledes i f.eks. vores nordiske nabolande, hvor man med lys og lygte leder efter kvalificeret sundhedspersonale. og netop af den grund er repræsentanter fra flere offentlige hospitaler i både sverige og norge og fra det grønlandske sundhedsvæsen i disse dage til jobmesse i københavn. med sig har flere hunderde jobtilbud til de danske, ledige sygeplejersker. dansk sygeplejeråd hilser initiativet fra medrek rekrytering - der som danmarks største jobhjemmeside inden for sundhedssektoren står bag jobmessen - velkommen, men langer samtidig ud efter beskæftigelsesminister mette frederiksen (s): "vi opfordrer de ledige sygeplejersker til at søge nogle af de mange ledige stillinger i udlandet i stedet for at gå ledig i danmark, men samtidig vil jeg sige: kære mette frederiksen - what a waste, for vi risikerer, at flere af dem ikke kommer tilbage, og om nogle få år har vi altså brug for kompetente sygeplejersker i danmark," siger anni pilgaard, der er 1. næsteformand i dansk sygeplejeråd. artiklen fortsætter under playeren ifølge anni pilgaard er der arbejdsopgaver nok til de ledige sygeplejersker i danmark - faktisk går flere sygeplejersker ned med stress: "samfundet har betalt for, at vi har veluddannede sygeplejersker, men på grund af den økonomiske politik er der ansættelsestop i mange kommuner, så vi har ikke råd til at give dem løn - og nu får udlandet så gavn af vores dygtige sygeplejersker," siger anni pilgaard. alligevel låner anni pilgaard "hjertens gerne" sygeplejerskerne ud til udlandet. hun vil hellere løbe risikoen for, at nogle sygeplejersker måske ikke kommer hjem igen, end at flere helt forlader sygeplejefaget. "jeg er overbevist om, at hvis man som arbejdsløs tager til udlandet, så bliver man meget mere attraktiv for ledere, når der bliver flere stillinger i danmark - man kommer helt klart op i bunken, når man har vist, at man ikke er gået i stå og er interesseret i at udvikle sine kompetencer," siger anni pilgaard. det er tredje gang, at medrek rekrytering afholder messen, og i år er der dobbelt så mange tilmeldinger som ved de to forrige messer i 2011. således har over 300 sygeplejersker tilmeldt sig messen. "i alt 11 arbejdsgivere fra norge, sverige og grønland deltager i messen. de efterspørger alt fra specialister til nyuddannede og har mere end 100 jobs at tilbyde. så hvis man virkelig ønsker et arbejde, så har man her muligheden," siger jesper fabæch fra medrek rekrytering. på messen deltager også udenlandske vikarbureauer og farmaceuter. mens ledigheden for farmaceuter også er stigende i danmark - der er sket en fordobling siden 2009 til 3 procent - er der blandt andet i norge også mangel på farmaceuter: "norske virksomheder rekrutterer farmaceuter fra polen og sætter dem på sprogkursus i seks måneder, inden de kommer til at arbejde i norge, så også her er der mulighed for danskere at få arbejde," siger jesper fabæch. nye tal fra dansk sygeplejeråd viser, at antallet af sygeplejersker der har søgt autorisation til at arbejde i sverige og norge næsten er tredoblet siden 2010.'

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Remove non-alphanumerical characters

# %%
for df in [ft_2, dr_2, tv2_2]:
    df['content'] = df['content'].str.replace(r'\W', ' ')\
                                 .str.replace('  ', ' ')
# Out:
# <ipython-input-3-73da12060138>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['content'] = df['content'].str.replace(r'\W', ' ')\

# %% [markdown]
# ## Tokenization

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/dana_tiger/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Define a tokenizer function
def tokenizer(df):
    df_tokenslist = []
    for document in tqdm.tqdm(df['content']):
        tokens = nltk.tokenize.word_tokenize(document, language = 'danish')
        df_tokenslist.append(tokens)
    df_tokens = list(itertools.chain(*df_tokenslist))
    return df_tokens

# %%
dr_2_tokens = tokenizer(dr_2)
print(len(dr_2_tokens))
tv2_2_tokens = tokenizer(tv2_2)
print(len(tv2_2_tokens))
ft_2_tokens = tokenizer(ft_2)
print(len(ft_2_tokens))
# Out:
# 100%|██████████| 528/528 [00:00<00:00, 548.94it/s]
#   3%|▎         | 97/3607 [00:00<00:03, 969.86it/s]
# 232998
# 100%|██████████| 3607/3607 [00:10<00:00, 348.14it/s]
#   0%|          | 0/296 [00:00<?, ?it/s]
# 2562567
# 100%|██████████| 296/296 [00:35<00:00,  8.40it/s]
# 7843399

# %% [markdown]
# ## Remove stopwords

# %%
# Get stopwords list
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('danish')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/dana_tiger/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Remove stopwords from tokenlist 
dr_without_stopwords = [word for word in dr_2_tokens if not word in stopwords]
tv2_without_stopwords = [word for word in tv2_2_tokens if not word in stopwords]
ft_without_stopwords = [word for word in ft_2_tokens if not word in stopwords]

# %%
full_wordlist = dr_without_stopwords + tv2_without_stopwords + ft_without_stopwords

# %%
len(dr_without_stopwords) + len(tv2_without_stopwords) + len(ft_without_stopwords)
# Out:
# 5356096

# %%
len(full_wordlist)
# Out:
# 5356096

# %% [markdown]
# ### Unique words

# %%
wordset_unique = set(full_wordlist)
len(unique_wordset)

wordlist_unique = list(unique_wordset)

# %%
wordlist_lem = [lem.lemmatize("", word) for word in wordset_unique]
wordlist_lem = [word for sublist in wordlist_lem for word in sublist]

# %% [markdown]
# ## Lemmatization

# %%
lem = lemmy.load("da")

# %%
#nltk.download('omw-1.4') #Download OpenMultilingualWordnet
#wnl = nltk.WordNetLemmatizer()

wordlist_lemma = [lem.lemmatize('', i) for i in wordset_unique]
wordlist_lemma
# Out:
# [['stalinistisk'],
#  ['mediere', 'medie'],
#  ['omstrukturering'],
#  ['subjektiv'],
#  ['enkeltbillet'],
#  ['åbenbare'],
#  ['sværejob'],
#  ['landsholdskammerat'],
#  ['boligområde'],
#  ['forældreinformation'],
#  ['knæk', 'knække'],
#  ['nøle', 'nøler'],
#  ['prikke', 'prik'],
#  ['aarhusiansk'],
#  ['måttetage'],
#  ['institut'],
#  ['blaffer'],
#  ['udbetaling'],
#  ['sprøjte'],
#  ['fredagshumør'],
#  ['herlighedsværdi'],
#  ['måtte'],
#  ['justering'],
#  ['busborg'],
#  ['blevde'],
#  ['rivravruskende'],
#  ['center'],
#  ['sauce'],
#  ['tydelighed'],
#  ['stifte'],
#  ['erhvervspolitik'],
#  ['integrerbar'],
#  ['sprudle'],
#  ['zandra'],
#  ['havretsdomstol'],
#  ['armenien'],
#  ['fremlæg', 'fremlægge'],
#  ['overenskomstforhandling'],
#  ['fingerknipsløsning'],
#  ['migrantsituation'],
#  ['afstemningsseddel'],
#  ['negligering'],
#  ['ingen'],
#  ['arbejdsmængde'],
#  ['lagdevægt'],
#  ['velkommen'],
#  ['hansom'],
#  ['hitte'],
#  ['løntilskudsområde'],
#  ['qaarsutte', 'qaarsut'],
#  ['ekstravagant'],
#  ['nedprioritere'],
#  ['dfg'],
#  ['lokalbefolkning'],
#  ['abildskov'],
#  ['tandholdt'],
#  ['baghjul'],
#  ['mennesketom'],
#  ['danish'],
#  ['lindeberg'],
#  ['mandshjerte'],
#  ['blodproptilstand'],
#  ['ansvarsområde'],
#  ['bgie', 'bgi'],
#  ['konfliktområde'],
#  ['kue'],
#  ['stikprøve'],
#  ['behandlingsskade'],
#  ['aktion'],
#  ['bæredygtighedsmæssig'],
#  ['cnbc'],
#  ['modvidnesbyrd'],
#  ['folkeskoleaftale'],
#  ['børnefysioterapeut'],
#  ['boligstandard'],
#  ['lærerformand'],
#  ['medlemsorganisation'],
#  ['verdenskrig'],
#  ['tvangsuddannelse'],
#  ['ophøre'],
#  ['yoko'],
#  ['hamre', 'hammer'],
#  ['line', 'liner'],
#  ['klædeskab'],
#  ['bære'],
#  ['grundudgangspunkt'],
#  ['skibumse', 'skibums'],
#  ['metropolskole'],
#  ['coronadødsfald'],
#  ['afhængigaffe', 'afhængigaf'],
#  ['wardinghus'],
#  ['ghettoplan'],
#  ['stridspunkt'],
#  ['fordring'],
#  ['frist'],
#  ['minutskema'],
#  ['opfordring'],
#  ['bedrift'],
#  ['tydeliggøre'],
#  ['organisatorisk'],
#  ['arbejdsgruppe'],
#  ['våbenkontrol'],
#  ['ressortminister'],
#  ['domstolsafgørelse'],
#  ['nickibille'],
#  ['márquez'],
#  ['filmkarriere'],
#  ['metangasudledning'],
#  ['retssystem'],
#  ['tilskudsordning'],
#  ['sulaiman'],
#  ['cutte'],
#  ['sigerfelixe', 'sigerfelix'],
#  ['almeninteresse'],
#  ['fradrage'],
#  ['jeremyfaust'],
#  ['genmateriale'],
#  ['tvangsgifte'],
#  ['bombardement'],
#  ['tilgive'],
#  ['vene'],
#  ['militærbase', 'militærbasis'],
#  ['etøjebliksbillede'],
#  ['pointererdog'],
#  ['velfærdsomkostninger'],
#  ['omkomme'],
#  ['udviklingsarbejde'],
#  ['testkitte', 'testkit'],
#  ['føde'],
#  ['selvbebrejdelse'],
#  ['metroselskab'],
#  ['skamrose'],
#  ['pilotforsøg'],
#  ['sportskamp'],
#  ['byggeri'],
#  ['basisydelse'],
#  ['vaccinere'],
#  ['udelukke'],
#  ['detsbesøgpå'],
#  ['andersensige', 'andersensig'],
#  ['udlænding'],
#  ['regeringskrise'],
#  ['durk'],
#  ['omstilling'],
#  ['formandskabsland'],
#  ['udpumpning'],
#  ['zulu'],
#  ['væve', 'væv'],
#  ['spilleautomat'],
#  ['væddemål'],
#  ['hønsehus'],
#  ['arbejdsskadesag'],
#  ['klassesafgangsbevis'],
#  ['deltagerkreds'],
#  ['retssag'],
#  ['taxatur'],
#  ['intensivafdeling'],
#  ['ordination'],
#  ['virusprotein'],
#  ['tjenerelev'],
#  ['praksisforskel'],
#  ['menflere'],
#  ['uhørt'],
#  ['supermarked'],
#  ['isygeplejerskefagethar', 'isygeplejerskefagethave'],
#  ['fotoprojekt'],
#  ['statskasse'],
#  ['genindførsel'],
#  ['kasse'],
#  ['grundplatform'],
#  ['fjerdeprogram'],
#  ['vaccineleverandør'],
#  ['ældretiltag', 'ældretiltage'],
#  ['helbredsønske'],
#  ['toiletblok'],
#  ['midsommer'],
#  ['årigeaxel'],
#  ['skriveri'],
#  ['valgurne'],
#  ['dosere'],
#  ['stigningstakt'],
#  ['skalblandt'],
#  ['lund'],
#  ['stikpille'],
#  ['afstemningsresultat'],
#  ['afgiftsperiode'],
#  ['bly'],
#  ['rigsretssag'],
#  ['puljeordning'],
#  ['politifolk'],
#  ['arnø'],
#  ['claudia'],
#  ['doktrin'],
#  ['hysterisk'],
#  ['senere', 'sen'],
#  ['pressesekretær'],
#  ['monopolisering'],
#  ['oversætter', 'oversætte'],
#  ['personalesituation'],
#  ['sanktionsspor', 'sanktionsspore'],
#  ['falster'],
#  ['udvidelse'],
#  ['1915'],
#  ['månedsskifte'],
#  ['balancere'],
#  ['forbedring'],
#  ['weekend'],
#  ['arbejdsskifte'],
#  ['afklaringsforløb'],
#  ['nonnenifølge'],
#  ['mægle', 'mægler'],
#  ['vækste', 'vækst'],
#  ['190'],
#  ['kerneydelse'],
#  ['sundhedsforvaltning'],
#  ['voksenliv'],
#  ['eftersøgning'],
#  ['trøste', 'trøster'],
#  ['fødekanal'],
#  ['årsopgørelse'],
#  ['sovetid'],
#  ['lützellind'],
#  ['tvangsadoption'],
#  ['præsidentfrue'],
#  ['sundhedsklinik'],
#  ['frister', 'frist'],
#  ['vicepolitiinspektør'],
#  ['købe'],
#  ['halespids'],
#  ['advare'],
#  ['skoleeksempel'],
#  ['håndbold'],
#  ['politibevogtning'],
#  ['stimulere'],
#  ['øl'],
#  ['butiksej'],
#  ['omkomme'],
#  ['smittefare'],
#  ['tonstung'],
#  ['havdambrug'],
#  ['delmøde'],
#  ['forskelligeformåen'],
#  ['oh'],
#  ['narre'],
#  ['komplementær'],
#  ['oplæringsforløb'],
#  ['584'],
#  ['lønforsikring'],
#  ['gymnasiedel'],
#  ['ungdomsformand'],
#  ['formulering'],
#  ['forsker'],
#  ['alanum'],
#  ['tiltrædelsesinterviewe', 'tiltrædelsesinterview'],
#  ['tilbøjelighed'],
#  ['vammel'],
#  ['kapacitetsgrænse'],
#  ['kampstof'],
#  ['belastningsgrad'],
#  ['dus'],
#  ['prioritetsliste'],
#  ['kapacitetpakke'],
#  ['normløshed'],
#  ['forskningssatsning'],
#  ['bedrager', 'bedrage'],
#  ['sundhedsuddannelse'],
#  ['småbørnsforælder'],
#  ['124'],
#  ['bildør'],
#  ['museum'],
#  ['ejendomsbeskatning'],
#  ['røntgenbillederog'],
#  ['dødsrapport'],
#  ['politiaftale'],
#  ['varde'],
#  ['modargumentere', 'modargument'],
#  ['tolkefejl'],
#  ['klysne'],
#  ['smelt', 'smelte'],
#  ['lydproblem'],
#  ['forsømme'],
#  ['sessionslogning'],
#  ['detailhandel'],
#  ['alcorcón'],
#  ['vaccinationssted'],
#  ['privatskoleområde'],
#  ['dumhed'],
#  ['integrationsydelse'],
#  ['velfærdsdumping'],
#  ['bestyrelsesarbejde'],
#  ['udledning'],
#  ['erhvervsinvestering'],
#  ['shali'],
#  ['akuthåndtering'],
#  ['nyhedsudvikling'],
#  ['tilskynde'],
#  ['skolebasere'],
#  ['hds'],
#  ['ugersfrist'],
#  ['sygdomsforløb'],
#  ['lag'],
#  ['undergrundsbane'],
#  ['videoindhold'],
#  ['styrmand'],
#  ['erichsenog'],
#  ['aflastningsfamilie'],
#  ['hovedarkitekt'],
#  ['vagtfolk'],
#  ['efterjustering'],
#  ['suspekt'],
#  ['migrationsudfordring'],
#  ['finanslovsreserve'],
#  ['vejgaard'],
#  ['fastlåse'],
#  ['genfinde'],
#  ['krisepolitik'],
#  ['høstrup'],
#  ['ædelsten'],
#  ['reduktion'],
#  ['g7'],
#  ['smartphone'],
#  ['behrende'],
#  ['åndelig'],
#  ['patientersamt'],
#  ['trippe', 'trip'],
#  ['johansen'],
#  ['skære'],
#  ['reklamekrone'],
#  ['kollektivisering'],
#  ['dialog'],
#  ['oplevelse'],
#  ['fare'],
#  ['petroleum'],
#  ['naturskov'],
#  ['fjällid'],
#  ['tiltale'],
#  ['psykolog'],
#  ['værnsregel'],
#  ['nøgle'],
#  ['lektor'],
#  ['imødegå'],
#  ['stifte'],
#  ['forbund'],
#  ['præstationsræs'],
#  ['sejpineri'],
#  ['videst'],
#  ['fiktionsserie'],
#  ['agitationssymbol'],
#  ['imødekomme'],
#  ['pasningsordning'],
#  ['produktersom'],
#  ['hjemsendelsesregime'],
#  ['amputere'],
#  ['talent'],
#  ['folketingspolitiker'],
#  ['pernille'],
#  ['somuniversitetsklinik'],
#  ['loggningssystem'],
#  ['verdensmål'],
#  ['parlamentsvalg'],
#  ['rygerbure', 'rygerbur'],
#  ['kemipakke'],
#  ['safari'],
#  ['vælgermæssig'],
#  ['rammeforsøg'],
#  ['opbygge'],
#  ['hyletone'],
#  ['regel'],
#  ['glas'],
#  ['drænoperation'],
#  ['sygedagpengemodtager'],
#  ['turbokursusforløb'],
#  ['medlemsstøtte'],
#  ['hospitalslukning'],
#  ['vande', 'vand'],
#  ['meditation'],
#  ['indenrigspolitisk'],
#  ['retsvæsenskommission'],
#  ['marstal'],
#  ['mobbe'],
#  ['varmediskussion'],
#  ['inkorporere'],
#  ['havtemperatur'],
#  ['portugiser'],
#  ['vestorm'],
#  ['forhandle'],
#  ['seniosergent'],
#  ['manifestere'],
#  ['jihad'],
#  ['frontière'],
#  ['meadows'],
#  ['uddannelse'],
#  ['kræftoverlevelse'],
#  ['almenvel'],
#  ['kompetencemæssig'],
#  ['populistisk'],
#  ['kongerige'],
#  ['sundhedsomåden'],
#  ['hjule'],
#  ['unik'],
#  ['sunde', 'sund'],
#  ['brødføde'],
#  ['sovepille'],
#  ['regeringspartnerliberal'],
#  ['donere'],
#  ['insulininjektion'],
#  ['male'],
#  ['looij'],
#  ['overlapning'],
#  ['airbag'],
#  ['pusher', 'pushe'],
#  ['1162'],
#  ['kærlighedsfyldt'],
#  ['fossilbil'],
#  ['elevrådsformand'],
#  ['sundhedsbaggrund'],
#  ['nonsens'],
#  ['gennemtestedeteori'],
#  ['handlingsplan'],
#  ['emotionel'],
#  ['diabetesforening'],
#  ['vejrprognose'],
#  ['boksetræning'],
#  ['grundforskningsfond'],
#  ['regnfuld'],
#  ['redningsmandskab'],
#  ['mentalundersøgelseen'],
#  ['fodpatient'],
#  ['signet', 'signe'],
#  ['streame'],
#  ['eder', 'ed'],
#  ['iagttage'],
#  ['asyldagsorden'],
#  ['ikkekvalificere'],
#  ['cassie'],
#  ['privatbolig'],
#  ['velfærdsordfører'],
#  ['fejlcitat'],
#  ['tøve'],
#  ['2022'],
#  ['fodboldstadion'],
#  ['log', 'logge'],
#  ['medicin'],
#  ['montre'],
#  ['omfejloperation'],
#  ['visir'],
#  ['sygdom'],
#  ['40'],
#  ['nexø'],
#  ['alskens'],
#  ['institutionsverden'],
#  ['proton'],
#  ['airline'],
#  ['tvivlsgruppe'],
#  ['meritokrati'],
#  ['gumme'],
#  ['ønske'],
#  ['7464'],
#  ['reguleringsform'],
#  ['svedig'],
#  ['rejsetidsgaranti'],
#  ['banenet'],
#  ['nødhjælpsorganisation'],
#  ['mfre'],
#  ['retspsykiatrisk'],
#  ['enigeu'],
#  ['bla'],
#  ['lød'],
#  ['pensionsbetaling'],
#  ['bakke'],
#  ['genere', 'gene', 'gen'],
#  ['deltaftale'],
#  ['mistrives'],
#  ['puha'],
#  ['skolesøgende'],
#  ['avistegning'],
#  ['forhale'],
#  ['bartramme', 'bartram'],
#  ['akutliste'],
#  ['kølle'],
#  ['overtalelse'],
#  ['energiunion'],
#  ['delikat'],
#  ['bevise'],
#  ['thorn'],
#  ['fimrehår'],
#  ['udbudsregel'],
#  ['575'],
#  ['torsdag'],
#  ['smittefælde'],
#  ['ikkekomme'],
#  ['risikere'],
#  ['kredsløbsforstyrrelse'],
#  ['barni'],
#  ['maske'],
#  ['behandlingsfaggruppe'],
#  ['formalisere'],
#  ['tvangsopløse'],
#  ['jordbærbod'],
#  ['resignere'],
#  ['referere'],
#  ['dissens'],
#  ['hovedkonklusion'],
#  ['folkeoplysning'],
#  ['båndoptager', 'båndoptage'],
#  ['nomi4s'],
#  ['opridse'],
#  ['indlånskonto'],
#  ['freetown'],
#  ['assistere'],
#  ['reproduktiv'],
#  ['partistøtteregel'],
#  ['varigt', 'varig'],
#  ['haus'],
#  ['stedvare'],
#  ['revisionsfirma'],
#  ['kviklån'],
#  ['sprængstof'],
#  ['nedgang'],
#  ['faglighed'],
#  ['johns'],
#  ['næstefter'],
#  ['psykiatrimiddel'],
#  ['club'],
#  ['førcaroline'],
#  ['fiskeriterritorie'],
#  ['voksenpsykiater'],
#  ['håndboldtræning'],
#  ['bliversende'],
#  ['anlægsmilliard'],
#  ['hvileperiode'],
#  ['leader'],
#  ['lift'],
#  ['denne', 'disse'],
#  ['teatertorden'],
#  ['nasre'],
#  ['kontanthjælpsniveau'],
#  ['kollegielejlighed'],
#  ['sigte'],
#  ['bührmann'],
#  ['koncentrere'],
#  ['537'],
#  ['snegletempo'],
#  ['stammeproblem'],
#  ['fortaltanklagemyndighed'],
#  ['510'],
#  ['transportsektor'],
#  ['børnekræftafdeling'],
#  ['artikel'],
#  ['regeringstid'],
#  ['tøris'],
#  ['foreskrive'],
#  ['07'],
#  ['syn', 'syne'],
#  ['lysegul'],
#  ['spiseforstyrrelse'],
#  ['prise'],
#  ['derigennem'],
#  ['drukning'],
#  ['høringsperiode'],
#  ['restpensionslevetid'],
#  ['områdeomstændighed'],
#  ['byrum'],
#  ['mosk'],
#  ['døgnpersonale'],
#  ['luftskib'],
#  ['donorregister'],
#  ['kompensationslønning'],
#  ['læringsmiddel'],
#  ['geopolitisk'],
#  ['gensynsglæde'],
#  ['devaluere'],
#  ['stimulere'],
#  ['griseri'],
#  ['indvandrerdebat'],
#  ['ledighedstal'],
#  ['annonce'],
#  ['bangui'],
#  ['årti'],
#  ['kandidatuddannet'],
#  ['education'],
#  ['elbus'],
#  ['e45'],
#  ['udenrigsminister'],
#  ['nordqvist'],
#  ['guiness'],
#  ['ejendomsret'],
#  ['inga'],
#  ['serviceforringelse'],
#  ['spøge'],
#  ['kampagnefolk'],
#  ['sanitær'],
#  ['rouhani'],
#  ['diligence'],
#  ['hærge', 'hærget'],
#  ['zombie'],
#  ['mistroisk'],
#  ['gazebind'],
#  ['besøge'],
#  ['della'],
#  ['alzheimerforening'],
#  ['fremsættelsestale'],
#  ['kaastrup'],
#  ['ogpædagog'],
#  ['mest'],
#  ['slide', 'slid'],
#  ['guitarist'],
#  ['panikagtig'],
#  ['katowice'],
#  ['genåbning'],
#  ['astronom'],
#  ['erhverv'],
#  ['retning'],
#  ['invalidere'],
#  ['hahaha'],
#  ['stokkebor'],
#  ['regnskabsarbejde'],
#  ['adhalgulv'],
#  ['indadvendt'],
#  ['bagklog'],
#  ['golfspille'],
#  ['kærlighedsgave'],
#  ['vægre'],
#  ['håndskreven', 'håndskrevet'],
#  ['12½'],
#  ['tilfælde'],
#  ['hund'],
#  ['institutionel'],
#  ['monokønnet'],
#  ['overlade'],
#  ['borgerkrig'],
#  ['famle'],
#  ['benfield'],
#  ['kampprogram'],
#  ['hospitalsengeplads'],
#  ['regnemaskine'],
#  ['dybtgående'],
#  ['udstå'],
#  ['bevillingsniveau'],
#  ['reformalliance'],
#  ['lovindgreb'],
#  ['iluc'],
#  ['anlægsstart', 'anlægsstarte'],
#  ['mundskylle'],
#  ['indvandrerspørgsmål'],
#  ['coronaafsnit'],
#  ['tidtagning'],
#  ['røgslør'],
#  ['nicholson'],
#  ['kaprer'],
#  ['energiklasse'],
#  ['rødvinsreform'],
#  ['ananasproducent'],
#  ['halse'],
#  ['exceptionel'],
#  ['graulund'],
#  ['1002'],
#  ['uartig'],
#  ['clemmens'],
#  ['manuskript'],
#  ['slæbe'],
#  ['tildelingskriterie'],
#  ['kvantemekanik'],
#  ['æresvold'],
#  ['uddannelsesområde'],
#  ['uddannelsesystem'],
#  ['arbejdsløshedsforsikring'],
#  ['familieafdeling'],
#  ['lovløshed'],
#  ['fastholdelsesbonus'],
#  ['kommunalpolitiker'],
#  ['menlig'],
#  ['432'],
#  ['kriminalitetsbekæmpelse'],
#  ['mægtig'],
#  ['folkepensionist'],
#  ['beliggende'],
#  ['andenrangs'],
#  ['kisteglad'],
#  ['virksomhedsansvarlig'],
#  ['forligstradition'],
#  ['paradigmeskift'],
#  ['ledig'],
#  ['leveti'],
#  ['webvært'],
#  ['regelgrundlag'],
#  ['overnatningssted'],
#  ['flerårsaftale'],
#  ['køreplan'],
#  ['faiza'],
#  ['alvorsgrad'],
#  ['kendetegne'],
#  ['bosætningsmønster'],
#  ['ørstedspark'],
#  ['arbejdedesam'],
#  ['ford'],
#  ['skvatte'],
#  ['vært'],
#  ['bourmanner'],
#  ['klimaindsats'],
#  ['nytårsaftensdag'],
#  ['uddannelsestradition'],
#  ['arealforbrug'],
#  ['forudgående', 'forudgå'],
#  ['våbenhvile'],
#  ['masse'],
#  ['dagkirurgi'],
#  ['omsætte'],
#  ['fortie'],
#  ['rumme'],
#  ['onsdag'],
#  ['omgøre'],
#  ['stabiliseringsbistand'],
#  ['menneskerettighedssituation'],
#  ['stationær'],
#  ['sammenkneben', 'sammenknebet'],
#  ['ændre'],
#  ['tilskudsramme'],
#  ['clap', 'clappe'],
#  ['ode'],
#  ['474'],
#  ['graviditetsdagbog'],
#  ['vaccinestik'],
#  ['pitt'],
#  ['blankocheck'],
#  ['flygtningelejr'],
#  ['rovdyr'],
#  ['klimasamarbejde'],
#  ['blindhed'],
#  ['bloktilskud'],
#  ['ardannelse'],
#  ['lortesituation'],
#  ['oghan', 'oghans'],
#  ['bebyggelsesprocent'],
#  ['erforegå'],
#  ['café'],
#  ['fremstilling'],
#  ['maharaj'],
#  ['frit'],
#  ['pc2rq1ww7z'],
#  ['amnestimodel'],
#  ['lycratøj'],
#  ['dønning'],
#  ['somuddanneri'],
#  ['turèll'],
#  ['teolog'],
#  ['samfundsfremgang'],
#  ['8000'],
#  ['smølf'],
#  ['dyne'],
#  ['leasingudfordring'],
#  ['ekstrainvestering'],
#  ['demonstration'],
#  ['østarbejder'],
#  ['nappe'],
#  ['vaccineindsats'],
#  ['pokal'],
#  ['akutnummer'],
#  ['bror'],
#  ['prisstigning'],
#  ['forhandlingsstab'],
#  ['tagge', 'tage', 'tag'],
#  ['bane'],
#  ['68'],
#  ['eliteenhed'],
#  ['tilgængelig'],
#  ['sæddonor'],
#  ['normaltbegavet'],
#  ['overraskerpå'],
#  ['glasproduktion'],
#  ['tregang'],
#  ['krænke'],
#  ['sektion'],
#  ['efterlønsreform'],
#  ['tristan'],
#  ['fingersandwich'],
#  ['beboelseskvarter'],
#  ['militarisere'],
#  ['decimaldiskussion'],
#  ['hofdame'],
#  ['skovsti'],
#  ['kæmpe'],
#  ['evaluation'],
#  ['sammenstødsproblem'],
#  ['skattekonkurrence'],
#  ['forløbsprogram'],
#  ['lægekollega'],
#  ['flaskehals'],
#  ['parallelsamfundsområde'],
#  ['beundre'],
#  ['friste', 'frist'],
#  ['bruse'],
#  ['anne'],
#  ['kulminere'],
#  ['produktivitetskrav'],
#  ['studiegruppe'],
#  ['turistforening'],
#  ['ungefaglig'],
#  ['ikkefaglært'],
#  ['årigefreja'],
#  ['beredskabsstyrke'],
#  ['uenighed'],
#  ['religiøsitet'],
#  ['334'],
#  ['bosætte', 'bosat'],
#  ['sporstof'],
#  ['rengøringsselskab'],
#  ['investeringsniveau'],
#  ['spidskandidat'],
#  ['agent'],
#  ['5230'],
#  ['drink'],
#  ['kompensationsordning'],
#  ['borgerhenvendelse'],
#  ['rekruttering'],
#  ['snitte', 'snit'],
#  ['bukke'],
#  ['858'],
#  ['højskolekammerat'],
#  ['uddannelsesliv'],
#  ['rødspætte'],
#  ['0501'],
#  ['fredningsnævn'],
#  ['landsforbund'],
#  ['vilkår'],
#  ['video'],
#  ['spørgsmål'],
#  ['granske'],
#  ['tudse'],
#  ['lavvandet'],
#  ['valggave'],
#  ['skatteministerie'],
#  ['forskermiljø'],
#  ['jeanne'],
#  ['kapitalgrundlag'],
#  ['dynamisk'],
#  ['livsindkomst'],
#  ['statsregulere'],
#  ['charly'],
#  ['spilletrøje'],
#  ['fortryde'],
#  ['naloxon'],
#  ['præstationsfremmende'],
#  ['wau'],
#  ['610'],
#  ['mellemmagt'],
#  ['vandkantsdanmark'],
#  ['regionsudvalg'],
#  ['menerstefan'],
#  ['skattegulerod'],
#  ['ingenvide'],
#  ['nordsøbeskatning'],
#  ['befrugte'],
#  ['fragte'],
#  ['forskningsassistent'],
#  ['produktidé'],
#  ['lydbeskeden', 'lydbesked'],
#  ['joboge', 'jobog'],
#  ['knoglebrud'],
#  ['sprøjtning'],
#  ['forsimple'],
#  ['mazurek'],
#  ['mindeplade'],
#  ['hjertestoppakke'],
#  ['arbejdsprøvning'],
#  ['lighedsskabende'],
#  ['strandbred'],
#  ['frokost'],
#  ['konfrontatorisk'],
#  ['servicepersonale'],
#  ['magtudredning'],
#  ['gård'],
#  ['sumobryderforening'],
#  ['kendelse'],
#  ['diskriminering'],
#  ['uvejsom'],
#  ['naturpleje'],
#  ['risicien'],
#  ['ecdc'],
#  ['harprøve'],
#  ['forveksling'],
#  ['produktivitetsforbedring'],
#  ['juleaftensnat'],
#  ['sirene'],
#  ['offentligtgøre'],
#  ['aktieindkomstbeskatning'],
#  ['sammensværgelse'],
#  ['movchan'],
#  ['selvstændig'],
#  ['826'],
#  ['conradsen'],
#  ['derfra'],
#  ['forhandlingsleder'],
#  ['akva'],
#  ['samfundsvigtig'],
#  ['emneskift'],
#  ['fragmentering'],
#  ['gude'],
#  ['hutle'],
#  ['kontrolmyndighed'],
#  ['psykolog'],
#  ['exitcenter'],
#  ['forskel'],
#  ['ønskeposition'],
#  ['forrykke'],
#  ['snobberi'],
#  ['mægtig'],
#  ['olaidag'],
#  ['berøring'],
#  ['centrere'],
#  ['ophobning'],
#  ['velgennemføre'],
#  ['operationshold'],
#  ['landekontor'],
#  ['góðu'],
#  ['indfri'],
#  ['protein'],
#  ['tiltage'],
#  ['lægedækningsudvalg'],
#  ['fødevaretrend'],
#  ['uddannelsespolitik'],
#  ['kamp'],
#  ['spotte'],
#  ['dokumentere'],
#  ['afslag'],
#  ['erhvervsordfører'],
#  ['sprogkurs'],
#  ['varmed'],
#  ['egoistisk'],
#  ['brandhamrende'],
#  ['ekspertområde'],
#  ['theodor'],
#  ['anatomi'],
#  ['omsætning'],
#  ['arbejdsudbudseffekt'],
#  ['stiftelse'],
#  ['koste', 'kost'],
#  ['føljeton'],
#  ['fyord'],
#  ['storbonde'],
#  ['donetsk'],
#  ['nulvækstregime'],
#  ['oprydningsopgave'],
#  ['bevægelighed'],
#  ['bevågenhed'],
#  ['melgaard'],
#  ['løbebog'],
#  ['fortjene'],
#  ['støj'],
#  ['krystalklar'],
#  ['misdannelserel'],
#  ['direktion'],
#  ['enhedschef'],
#  ['fangebur'],
#  ['konsekvensvurdering'],
#  ['simpsone'],
#  ['fremmedkriger'],
#  ['saltbalance'],
#  ['græstype'],
#  ['natnat'],
#  ['værditilvækst'],
#  ['sukke', 'suk'],
#  ['skattefavorisering'],
#  ['meddele'],
#  ['deponi'],
#  ['forgiftningssymptom'],
#  ['minimumsniveau'],
#  ['elbil'],
#  ['kræve'],
#  ['lynnedslag'],
#  ['regnskab'],
#  ['gin'],
#  ['gungre'],
#  ['klimagasse', 'klimagas'],
#  ['mætte'],
#  ['detective'],
#  ['kano'],
#  ['johnny'],
#  ['kaskoforsikre'],
#  ['familie'],
#  ['fixerum'],
#  ['pensionsvilkår'],
#  ['kortslutte'],
#  ['fodboldherre'],
#  ['coachella'],
#  ['indefrysning'],
#  ['alarmere'],
#  ['guido'],
#  ['modpart'],
#  ['enighed'],
#  ['baggrund'],
#  ['afstive'],
#  ['leasinggæld', 'leasinggælde'],
#  ['1304'],
#  ['daglejervilkår'],
#  ['solcellefællesskab'],
#  ['deirdre'],
#  ['smart'],
#  ['farmaceut'],
#  ['myndighedsvurdering'],
#  ...]

# %%
items = ['1','introduction','to','molecular','8','the','learning','module','5']

new_items = [item for item in items if not item.isdigit()]

# %%
new_items
# Out:
# ['introduction', 'to', 'molecular', 'the', 'learning', 'module']

# %%
# Load Danish lemmatizer
lem = lemmy.load("da")

# %%
# Out:
# ['sygeplejerske']

# %%
for df in [ft_2, dr_2, tv2_2]:
    df['content_lem'] =

# %%
# Out:
# Collecting lemmyNote: you may need to restart the kernel to use updated packages.
#   Downloading lemmy-2.1.0-py2.py3-none-any.whl (1.1 MB)
# Installing collected packages: lemmy
# Successfully installed lemmy-2.1.0
