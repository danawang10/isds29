# %% [markdown]
# # Analysis of usage of the term "sygeplejersker" in DR, TV2 and the danish parliament

# %% [markdown]
# ## Extract content of zip

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import csv
import re
import time
import tqdm
import zipfile
from datetime import datetime
import warnings
warnings.simplefilter(action='ignore',category=FutureWarning)
import itertools

# Plotting
import seaborn as sns
import matplotlib.pyplot as plt

# Selenium
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# Scraping
import requests
from bs4 import BeautifulSoup as bs
import os
import lxml
from lxml import objectify
import ftplib
from io import BytesIO

#Text processing
from nltk.stem import SnowballStemmer
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfTransformer
from PIL import Image
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jgb569\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### DR

# %% [markdown]
# > NOTE: The following code must be run on a computer with danish language as google behaves differently based on the computers language settings

# %% [markdown]
# #### 1:  Generate search terms
#
# Search terms follow the following format: We search for the month and year in the format DR articles inclue a timestap. Manual Google searches proved to provide relevant research results mostly limited to the month provided. In this way we create a list of links to DR articles. All articles are located on the site https://www.dr.dk/nyheder or a subsite. This can be included in the google search. An example of a search is: jan. 2012" AND "sygeplejersker*" site:https://www.dr.dk/nyheder.

# %%
# Generate empty list with search terms
search_terms = []
# Generate combinations of year-month and term search combinations
for year in range(2012, 2023):
    months = ['jan.', 'feb.', 'mar.', 'apr.', 'maj', 'jun.', 'jul.', 'aug.', 'sep.', 'okt.', 'nov.', 'dec.']
    for month in months:
        term = f'"{month} {year}" AND "sygeplejersker*" site:https://www.dr.dk/nyheder/ \n'
        search_terms.append(term)
# Create final list of search terms, future month-year combinations deleted
search_terms = search_terms[:-4]

# %% [markdown]
# We create a total of 124 search terms, for all month-year combinations between January 2012 and August 2022.

# %% [markdown]
# #### 2a: Scraping Google search to retrieve list of links to DR articles
# With the following code we scrape Google searches to retrieve a list of links to DR articles, given the DR website does not provide a useful search function. We use Selenium to go execute a Google search and retrieve DR article links. We execute the search, save the HTML for the first results page and then go to further pages of the search results to retrieve more search resutls. Google intervenes when scaping search results too fast. We therefore integrate a break when moving between pages. The break time takes random values between 0.25 and 3.5 seconds.

# %% [markdown]
# Scraping the first three search pages:

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
html_list = []
finished_searches = 0

for i in tqdm.tqdm(search_terms[0:1]):
    # Go to google
    driver.get('https:google.com')
    # Discard cookie message, reject cookies
    cookie = driver.find_element(By.ID, "W0wltc")
    cookie.click()
    # Search for DR news articles
    gsearch = driver.find_element(By.CSS_SELECTOR, "input[title='Søg']")
    gsearch.send_keys(i)
    # Get HTML for first search result page
    html = driver.page_source
    html_list.append(html)
    # Go to next result page
    next_page = driver.find_element(By.CSS_SELECTOR, ".NVbCr+ span") #CSS selector only last not previous page
    next_page.click()
    # Define an error used when reaching last search page:
        # When error = 0, there is another resut page.
        # When error = 1, there is no further page on Google, loop stops.
    error = 0
    page = 1
    for page in range(0,1): #Iterates over 3 Pages in total
        try:
            html2 = driver.page_source
            html_list.append(html2)
            # Google detects suspicious behavior and asks to solve some puzzle after 7 iterations. Trying random sleep time and scrolling down to element.
            time.sleep(np.random.uniform(10, 15))
            # Go to next result page
            next_page = driver.find_element(By.CSS_SELECTOR, "#pnnext .NVbCr+ span") #CSS selector only last not previous page
            next_page.click()
            page += 1
        except:
            error += 1
    finished_searches += 1
    time.sleep(np.random.uniform(5,10))
    driver.quit()
# Out:
# C:\Users\jgb569\AppData\Local\Temp/ipykernel_17548/3444555280.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# 100%|██████████| 1/1 [00:37<00:00, 37.31s/it]

# %% [markdown]
# #### 2b: Scraping number of google results for search terms

# %%
num_search_results = []

for search_term in tqdm.tqdm(search_terms[0:1]):
    driver = webdriver.Chrome(ChromeDriverManager())
    # Go to google
    driver.get('https:google.com')
    # Discard cookie message, reject cookies
    cookie = driver.find_element(By.ID, "W0wltc")
    cookie.click()
    # Search for DR news articles
    gsearch = driver.find_element(By.CSS_SELECTOR, "input[title='Søg']")
    gsearch.send_keys(search_term)
    # Get HTML for first search result page
    num_results = driver.find_element(By.ID, "result-stats")
    num_search_results.append(num_results.text)
    time.sleep(np.random.uniform(0.25,1))
    driver.quit()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]C:\Users\jgb569\AppData\Local\Temp/ipykernel_17548/952643850.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager())
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17548/952643850.py in <module>
#       2
#       3 for search_term in tqdm.tqdm(search_terms[0:1]):
# ----> 4     driver = webdriver.Chrome(ChromeDriverManager())
#       5     # Go to google
#       6     driver.get('https:google.com')
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      67             service = Service(executable_path, port, service_args, service_log_path)
#      68
# ---> 69         super().__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      70                          port, options,
#      71                          service_args, desired_capabilities,
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\chromium\webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      87
#      88         self.service = service
# ---> 89         self.service.start()
#      90
#      91         try:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      69             cmd = [self.path]
#      70             cmd.extend(self.command_line_args())
# ---> 71             self.process = subprocess.Popen(cmd, env=self.env,
#      72                                             close_fds=system() != 'Windows',
#      73                                             stdout=self.log_file,
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     949                             encoding=encoding, errors=errors)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#     953                                 startupinfo, creationflags, shell,
#
# ~\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1358                 args = list2cmdline([args])
#    1359             else:
# -> 1360                 args = list2cmdline(args)
#    1361
#    1362             if executable is not None:
#
# ~\Anaconda3\lib\subprocess.py in list2cmdline(seq)
#     563     result = []
#     564     needquote = False
# --> 565     for arg in map(os.fsdecode, seq):
#     566         bs_buf = []
#     567
#
# ~\Anaconda3\lib\os.py in fsdecode(filename)
#     820         'mbcs' (which is the default encoding).
#     821         """
# --> 822         filename = fspath(filename)  # Does type-checking of `filename`.
#     823         if isinstance(filename, bytes):
#     824             return filename.decode(encoding, errors)
#
# TypeError: expected str, bytes or os.PathLike object, not ChromeDriverManager

# %%
# Create list of search result counts
num_search_results_clean = []
for result in num_search_results:
    number_only = result[3:10]
    number_only = number_only.strip()
    number_only = re.sub('\D+', '', number_only)
    num_search_results_clean.append(number_only)

# %%
# Change to integer
list_search_results = [int(search) for search in num_search_results_clean]

# %%
# Creating a pd.DataFrame from search result count
list_search_results_df = pd.DataFrame({'Month': list_search_results}) # 'MONTH' SHOULD BE 'SEARCH_RESULTS'!

# %%
# Export 
list_search_results_df.to_csv("dr_google_search_results_sample.csv")

# %% [markdown]
# #### 3: Create link list

# %%
# Preparing two empty lists
link_list = []
link_list_clean = []
# Iterating over the results from scraping
for l in html_list:
    soup = bs(l, 'lxml')
    try: 
        links = soup.find('div', class_ = 'v7W49e').find_all('a', href=True)
    except:
        pass
    # Generate list with all links
    for i in links:
        temp = i['href']
        link_list.append(temp)
    # Getting rid of noise, links not pointing to DR but Google infrastructure
    for link in link_list:
        if "webcache.googleusercontent" not in link:
            link_list_clean.append(link)

# %% [markdown]
# #### 4: From list to DataFrame

# %%
# Creating a pd.DataFrame from link_list_clean
dr_links = pd.DataFrame({'links':link_list_clean})
# For some reason, there are many duplicates included, drop them
dr_links = dr_links.drop_duplicates(subset = 'links')

# %%
# Defining empty list for features
dr_titles_list = []
dr_h2_list = []
dr_date = []
dr_content_list = []
dr_author_list = []
dr_subhead_list = []
dr_tag_list = []

# Looping over links to retrieve HTMLs and extract relevant information from webpages
for u in tqdm.tqdm(dr_links["links"]):
    re = requests.get(u, headers = {"Name" : "Simon Ullrich - summer course project" , "email": "simon.ullrich@sodas.ku.dk"})
    soup = bs(re.content, "lxml")
    # Extracting article titles
    try:
        title = soup.find("div", class_ = "dre-speech")
        dr_titles_list.append(title.text)
    except:
        dr_titles_list.append("")
    # Extracting date of publication
    try:
        try:
            date = soup.find("time", class_ = "dre-byline__date")['datetime']
            dr_date.append(date)
        # Some websites are of another type. Date of publication located elsewhere on the website
        except:
            # Different website type: e.g. https://www.dr.dk/nyheder/da-lille-rikke-loeb-ind-i-margrethe
            date = soup.find("div", class_ = "hydra-latest-news-page-short-news__top").find("span", class_ = "dre-label-text__text")
            dr_date.append(pd.to_datetime(date.text))
    except:
        dr_date.append("")
    # Extracting author of articles
    try:
        author = soup.find("div", class_ = "dre-byline__contribution-details")
        dr_author_list.append(author.text)
    except:
        dr_author_list.append("")
    # Extracting subheaders
    try:
        subheader = soup.find("p", class_ = "dre-article-title__summary")
        dr_subhead_list.append(subheader.text)
    except:
        dr_subhead_list.append("")
    # Extracting article bodies
    try:
        # try:
        dr_content_i_list = []
        dr_content = soup.find_all("p", class_ = "dre-article-body-paragraph dre-variables")
        for i in dr_content:
            dr_content_i_list.append(i.text)
        dr_content_str = " ".join(dr_content_i_list)
        dr_content_list.append(dr_content_str)
        # except:
            # dr_content_i_list = []
            # dr_content = soup.find("div", class_ = "hydra-latest-news-page-short-news__body")
            # for i in dr_content:
                # dr_content_i_list.append(i)
                # dr_content_str = " ".join(dr_content_i_list)
            # dr_content_list.append(dr_content_str)
    except:
        dr_content_list.append("")
    # Extracting second headlines
    try:
        dr_h2 = soup.find_all("h2", class_ = "dre-article-body-sub-heading dre-variables")
        dr_h2_i_list = []
        for i in dr_h2:
            dr_h2_i = i.get_text()
            dr_h2_i_list.append(dr_h2_i)
        dr_h2_str = " ".join(dr_h2_i_list)
        dr_h2_list.append(dr_h2_str)
    except:
        dr_h2_list.append("")
    # Extracting article tags
    try:
        dr_tag = soup.find("a", class_ = "dre-article-title-section-label__title dre-article-title-section-label__title--link")
        dr_tag_list.append(dr_tag.text)
    except:
        dr_tag_list.append("")

# %%
### Combine lists to DataFrame
dr_articles_sample=pd.DataFrame([dr_titles_list, dr_subhead_list, dr_h2_list, dr_content_list, dr_author_list, dr_tag_list, dr_date, link_list_clean["links"]]).transpose()
dr_articles_sample.columns=["titles", "sub_header", "h2", "content", "author", "tag", "date", "link"]
dr_articles_sample["source"] = "DR"

display(dr_articles_test)

# %% [markdown]
# #### 5: Save sample dataset and load complete dataset

# %%
### Save dataset
dr_articles_sample.to_csv("dr_articles_sample.csv", index = False)

# %% [markdown]
# ### TV2

# %% [markdown]
# #### 1:  Generate search terms

# %%
links=[]
for year in range(2012, 2023, 1):
    year=f"https://search.tv2.dk/?query=sygeplejersker+{year}"
    
    for month in range(1,10,1): #Måned 1-9
        search_month=f"-0{month}&sort=relevance&page="
        
        for page in range(1,11,1): # (start, stop, step)
            url = year+search_month+f"{page}"
            links.append(url)
    
    for month in range(10, 13): #måned 10-12
        search_month=f"-{month}&sort=relevance&page="
        
        for page in range(1,11,1): # (start, stop, step)
            url = year+search_month+f"{page}"
            links.append(url)

# %%
tv2_article_list=pd.DataFrame(links)
tv2_article_list.to_csv("tv2_links_to_articles.csv")

# %% [markdown]
# #### 2: Scraping TV2 searches for links to articles and create list

# %%
article_url=[]
for i in tqdm.tqdm(links[0:2]):
    try:
        resp_page = requests.get(i,headers={"Name" : "Oliver Fredborg Smietana" , "email": "kph383@ku.alumni.dk"})
        soup = bs(resp_page.content, 'lxml')
        for link in soup.find("section").find_all('a', href=True):
            article_url.append(links['href'])
    except:
        pass
    time.sleep(0.25)

# %% [markdown]
# #### 3: Scraping articles from links list

# %%
titles_list=[]
h2_list=[]
date_list=[]
content_list=[]
author_list=[]
sub_head_list=[]
tag_list=[]

#  Define start and end of article loop
start=0
end=15


for u in tqdm.tqdm(article_url[start: end]) :
    re=requests.get(u, headers={"Name" : "Oliver Fredborg Smietana" , "email": "kph383@alumni.ku.dk", "Purpose": "exam project for Copenhagen uni Course" })
    soup=bs(re.content, "lxml")
    try:
        title=soup.find("h1", class_="tc_heading tc_heading--2")
        titles_list.append(title.text.strip())
    except:
        titles_list.append("")

    try:
        date=soup.find("time", class_="tc_timestamp")['datetime']
        date_list.append(date)
    except:
        date_list.append("")

    try:
        h2=soup.find_all("h2", class_="tc_heading tc_heading--2")
        h2_i_list=[]
        for i in h2:
            h2_i=i.get_text()
            h2_i_list.append(h2_i)
        h2_str=" ".join(h2_i_list)
        h2_list.append(h2_str)
    except:
        h2_list.append("")

    try:
        sub_head=soup.find("p", class_="tc_page__body__standfirst")
        sub_head_list.append(sub_head.text.strip())
    except:
        sub_head_list.append("")

    try:
        author=soup.find("span", class_="tc_byline__author__text")
        author_list.append(author.text.strip())
    except:
         author_list.append("")

    try:
        content_i_list=[]
        content_i=soup.find("div", class_="tc_richcontent").find_all("p")
        for i in content_i:
            content_i_list.append(i.text.strip())
        content_str=" ".join(content_i_list)
        content_list.append(content_str)
    except:
        content_list.append("")

    try:
        tag=soup.find("a", class_="tc_label tc_label--color-base-red")
        tag_list.append(tag.text.strip())
    except:
        tag_list.append("")

    time.sleep(0.25)

# %% [markdown]
# #### 4: Creating dataframe from scraped articles

# %%
tv2_articles_sample=pd.DataFrame([titles_list, sub_head_list, h2_list, content_list, author_list, tag_list, date_list, links[start:end]]).transpose()
tv2_articles_sample.columns=["titles", "sub_header", "h2", "content", "author", "tag", "date", "link"]
tv2_articles["source"]="tv2"

# %% [markdown]
# #### 5: Save sample dataset

# %%
tv2_articles.to_csv("tv2_articles_sample.csv", index=False)

# %% [markdown]
# ### Folketinget

# %% [markdown]
# #### 1: Create empty lists for loading data

# %%
# Empty lists for loading data
dirs = [] 
sub_dir = []
files = []
file_name = [] 
paths = []
raw_xml_list = []

# Empty lists for DataFrame creation (columns)
session = []
meetingnumber = []
date = []
location = []
group = []
content = []
path = []

# %% [markdown]
# #### 2: Logon to ftp server and get a list of dictionaries containing transscripted meetings in Folketinget

# %%
ftp_url = "oda.ft.dk"
ftp_dir = "/ODAXML/Referat/samling/"

# %%
ftp = ftplib.FTP(ftp_url)
ftp.login("anonymous", "wpg345@alumni.ku.dk")
ftp.set_pasv(True)
ftp.cwd(ftp_dir)
ftp.dir(dirs.append)

# %% [markdown]
# #### 3: Creates a list of sub-dir's

# %%
for i in range (0, len(dirs), 1):    # bygger en liste med underbiblioteker
    sub_dir.append(ftp_dir+dirs[i][-5:]+'/') 
    
for i in range (0, len(sub_dir), 1): # bygger en liste med filnavne
    ftp.cwd(sub_dir[i])
    ftp.dir(files.append)

for i in range(0, len(files)):       # extract filnavn
    file_name.append(files[i][39:])   

for i in range(0, len(file_name)):   # opbygning af den fulde sti og filnavn
    paths.append(ftp_dir+file_name[i][0:5]+'/'+file_name[i])

# %% [markdown]
# _All transscripted meetings are transferred from ftp://oda.ft.dk and the content is written to raw_xml_list_

# %% [markdown]
# The following code reads all 1489 meeting resumes from ft.dk - don't run! :

# %%
#for i in tqdm.tqdm(range(0, len(paths))):
#    r = BytesIO()
#    ftp.retrbinary(f"RETR {paths[i]}", r.write)
#    raw_xml_list.append(r.getvalue())
#    r.close()

# %% [markdown]
# The following code reads 10 meeting resumes from ft.dk :

# %%
for i in tqdm.tqdm(range(0, 10)):
    r = BytesIO()
    ftp.retrbinary(f"RETR {paths[i]}", r.write)
    raw_xml_list.append(r.getvalue())
    r.close()

# %% [markdown]
# #### 4: Define function

# %% [markdown]
# Metadata function:

# %%
def extract_metadata(xml):
    soup = bs(xml, 'lxml')
    
    d = soup.find("dateofsitting").text[:10]
    m = soup.find("meetingnumber").text
    s = soup.find("parliamentarysession").text
    g = soup.find("parliamentarygroup").text
    l = soup.find("location").text
    
    # antal gange de samme metadata gentages for hvert dagordenpunkt
    repeats = len(soup.find_all("dagsordenpunkt")) 
    
    for repeat in range(0, repeats):
        date.append(d)
        meetingnumber.append(m)
        session.append(s)
        group.append(g)
        location.append(l)
    
    return None

# %% [markdown]
# Content function:

# %%
def extract_content(xml): 
    soup = bs(xml, 'lxml')
    dagsordenpunkter = soup.find_all("dagsordenpunkt") # liste med dagsordenpunkter
    #print(f"Antal dagsordenpunkter: {len(dagsordenpunkter)}")
    
    for dp in dagsordenpunkter: # find raw xml-sætninger for hvert dagsordenpunkt
        sentences_raw = dp.find_all("linea") # liste med raw sætninger 
        #print(f"Antal sentences_raw: {len(sentences_raw)}")
        
        sentences_text = []
        
        for sr in sentences_raw: # for hver raw sætning, kør .text af sætningen
            sentences_text.append(sr.get_text(separator = ' ')) # gem clean sætninger til liste
        
        content.append(' '.join(sentences_text).strip()) # join, strip og append clean sætninger til liste
        #print(f"Antal content: {len(content)}")

    return None

# %% [markdown]
# Path function:

# %%
repeats = []

def extract_path(xml_list):
    
    for xml in xml_list: 
        soup = bs(xml, 'lxml')
        repeats.append(len(soup.find_all("dagsordenpunkt")))
    
    for i in range(0, len(xml_list)): 
        p = paths[i]
        path.extend([p] * repeats[i]) 
        #extend acts as append but multiplied by n times
    
    return None

# %% [markdown]
# #### 5: Run the functions and extract all the data

# %% [markdown]
# Meeting metadata:

# %%
for xml in tqdm.tqdm(raw_xml_list): 
    extract_metadata(xml)

# %% [markdown]
# Meeting content:

# %%
for xml in tqdm.tqdm(raw_xml_list): 
    extract_content(xml)

# %% [markdown]
# Path to original meeting resume:

# %%
extract_path(tqdm.tqdm(raw_xml_list))

# %% [markdown]
# #### 6: Make DataFrame containing needed data for analysis

# %%
ft = pd.DataFrame([session, meetingnumber, date, location, group, content, path]).transpose()
ft.columns = ['session', 'meetingnumber', 'date', 'location', 'group', 'content', 'path']

# %% [markdown]
# Changeing date column for text to date format:

# %%
ft['date'] = pd.to_datetime(ft['date'])

# %% [markdown]
# Only keeping data where date >= 2012:

# %%
ft = ft[ft['date'].dt.year >= 2012]

# %% [markdown]
# #### 7: Save DataFrame to ft.csv in your `local` working directory

# %%
ft.to_csv('ft_sample.csv.zip', index = False, compression='zip')

# %% [markdown]
# <p style="color:red"> Don't save the entire dataset to GitHub due to space limitation</p>

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# The complete datasets are loaded from the local folder:

# %%
tv2=pd.read_csv("tv2_articles.csv")
dr=pd.read_csv("dr_articles.csv")
dr_google_search_results=pd.read_csv("dr_google_search_results.csv")
# open zipped ft data set
with zipfile.ZipFile("ft.zip") as z:
   # open the csv file in the dataset
   with z.open("ft.csv") as f:
       
      # read the dataset
        ft = pd.read_csv(f)

# %% [markdown]
# TV2: The raw dataset after scraping websites from links has 8758 articles.
#
# DR: The raw dataset after scraping websites from links has 2065 articles.
#
# FT: The raw dataset after extraction has 13917 agenda items (dagsordenspunkter)

# %% [markdown]
# ### Initial cleaning operations

# %% [markdown]
# #### 1: DR Datasets

# %% [markdown]
# We found 538 observations for which no content was retrieved. These include articles with a different HTML structure (see, e.g.: 'https://www.dr.dk/nyheder/region-ingen-fare-patienter-paa-holbaek-sygehus?focusId=3406239'). Unfortunately, our scraping code did not account for this structure. If we had more time, we would go back, adapt the code and get the content of these articles. For the purpose of this limited analysis, we continue without those articles.

# %% [markdown]
# DR articles:

# %%
dr = dr.dropna(subset = ["content"]).reset_index(drop = True)

# %%
dr['date'] = pd.to_datetime(dr['date'])
dr = dr[dr['date'].dt.year >= 2012]
dr = dr.drop_duplicates(subset="content")
len(dr)
# Out:
# 1470

# %% [markdown]
# After dropping observations without content, 1470 articles remain.

# %% [markdown]
# Dr google search count data:

# %%
# Generate combinations of year-month
month_year = []
for year in range(2012, 2023):
    months = ['jan.', 'feb.', 'mar.', 'apr.', 'maj', 'jun.', 'jul.', 'aug.', 'sep.', 'okt.', 'nov.', 'dec.']
    for month in months:
        time = f'{month} {year}'
        month_year.append(time)
# Create final list of search terms, future month-year combinations deleted
month_year = month_year[:-4]

# %%
dr_google_search_results
# Out:
#      Unnamed: 0  Month
# 0             0   2220
# 1             1   1450
# 2             2   1360
# 3             3   1310
# 4             4   1700
# ..          ...    ...
# 123          73   1160
# 124           0  10600
# 125           1     22
# 126           2    423
# 127           3   3030
#
# [128 rows x 2 columns]

# %%
# Delete obsolete index column
dr_google_search_results.drop("Unnamed: 0", axis = "columns", inplace = True)

# Column name should be different: 'Month' but 'search_results'
dr_google_search_results = dr_google_search_results.rename(columns = {"Month" : "search_results"})

# %%
dr_google_search_results["month"] = month_year

# %%
dr_google_search_results
# Out:
#      search_results      month
# 0              2220  jan. 2012
# 1              1450  feb. 2012
# 2              1360  mar. 2012
# 3              1310  apr. 2012
# 4              1700   maj 2012
# ..              ...        ...
# 123            1160  apr. 2022
# 124           10600   maj 2022
# 125              22  jun. 2022
# 126             423  jul. 2022
# 127            3030  aug. 2022
#
# [128 rows x 2 columns]

# %% [markdown]
# #### 2: TV2 Dataset

# %%
## Rows that stem from links to a search page. They have the title "Søg på TV 2" and can be deleted
tv2 = tv2[tv2.titles != 'Søg på TV 2'].reset_index(drop = True)
# After this step, 7416 observations remain
# In the next step we drop all rows that do not contain values. These are sports artciles like this one: https://sport.tv2.dk/2012-02-26-sur-s%C3%B8d-fornemmelse-hos-kasper-hvidt
tv2 = tv2.dropna(subset = ['content'])
# Reset index
tv2 = tv2.reset_index(drop = True)
# Change date to date_time objects
tv2['date'] = pd.to_datetime(tv2['date'])
# Drop articles published outside period of interest (2012-2022)
tv2 = tv2[tv2['date'].dt.year >= 2012]
# Drop duplicates
tv2 = tv2.drop_duplicates(subset="content")
len(tv2)
# Out:
# 4473

# %% [markdown]
# Number of observations and rows: TV2 dataset now contains 4473 articles.

# %% [markdown]
# #### 3: Folketinget

# %%
## Rows that stem from links to a search page. They have the title "Søg på TV 2" and can be deleted
ft = ft[ft['content'].str.contains("sygeplej")]
ft['source'] = 'FT'
# Reset index
ft = ft.reset_index(drop = True)
# Change date to date_time objects
ft['date'] = pd.to_datetime(ft['date'])
ft['session'] = ft['session'].astype(int)
ft['meetingnumber'] = ft['meetingnumber'].astype(int)
display(len(ft))
# Out:
# 524

# %% [markdown]
# Number of observation (dagsordenspunkter) is now 524

# %% [markdown]
# #### 4: Columns of DR and TV datasets:
# * `titles` contains the articles' title
# * `sub_header` contains the articles' subheader
# * `h2` contains any headline found in the article
# * `author` contains the author of the article
# * `tag` contains any tags that TV2 added to the article: e.g. "udland".
# * `source` will later indicate the source
# * `links` contains the link to the original article
# * `date` contains date in the datetime formate

# %% [markdown]
# ### Cleaning articles' content

# %%
def cleaning_media(df):
    '''
    Function cleans the text of the "content", "titles", "subheaders" and "h2" columns of TV2 and DR datasets.
    '''
    df_new = df.copy()
    for i in tv2[['titles', 'sub_header', 'h2', 'content', 'author']]:
        df_new[i] = df_new[i].str.lower()\
            .str.replace('\r', '')\
            .str.replace('\n', '')\
            .str.replace('\xa0', '')
    return df_new

# %%
def cleaning_ft(df):
    '''
    Function cleans the text of the "content" column of FT dataset.
    '''
    df_new = df.copy()
    for i in ft[['content']]:
        df_new[i] = df_new[i].str.lower()\
            .str.replace('\r', '')\
            .str.replace('\n', '')\
            .str.replace('\xa0', '')
    return df_new

# %%
# Cleaning media with cleaning function
tv2 = cleaning_media(tv2)
dr = cleaning_media(dr)

# Cleaning ft with cleaning function
ft = cleaning_ft(ft)

# %% [markdown]
# ## Pre-processing datasets
#
# Creating different DataFrames according to the number of times "sygeplej*" is found in the articles' agenda items' (dagsordenspunkts) content for DR, TV2 and Folketinget, respectively. The more frequently the term features in the text, the more relevant the articles' should be for our analysis.

# %% [markdown]
# ### Experimenting with filters on our articles to get most relevant results

# %% [markdown]
# #### 1: Defining function

# %%
# Create different datasets with "sygeplej*" featuring at least X times in the text
def sygeplej_count(df):
    df_sygeplej1x = df[df['content'].str.count("sygeplej") >= 1]
    df_sygeplej2x = df[df['content'].str.count("sygeplej") >= 2]
    df_sygeplej3x = df[df['content'].str.count("sygeplej") >= 3]
    df_sygeplej4x = df[df['content'].str.count("sygeplej") >= 4]
    return df_sygeplej1x, df_sygeplej2x, df_sygeplej3x, df_sygeplej4x

# %% [markdown]
# #### 2: Using function on our datasets

# %%
tv2_sygeplej1x, tv2_sygeplej2x, tv2_sygeplej3x, tv2_sygeplej4x = sygeplej_count(tv2)
dr_sygeplej1x, dr_sygeplej2x, dr_sygeplej3x, dr_sygeplej4x = sygeplej_count(dr)
ft_sygeplej1x, ft_sygeplej2x, ft_sygeplej3x, ft_sygeplej4x = sygeplej_count(ft)

# %% [markdown]
# #### 3: Exploring the sygeplej* count across articles for DR and TV2 datasets

# %%
dict_sygeplej_count = {"sygeplej* count in each document":\
                       ['At least once', 'At least twice', 'At least three times', 'More than three times'],\
                       "DR" :\
                       [len(dr_sygeplej1x), len(dr_sygeplej2x), len(dr_sygeplej3x), len(dr_sygeplej4x)],\
                       "TV2" :\
                       [len(tv2_sygeplej1x), len(tv2_sygeplej2x), len(tv2_sygeplej3x), len(tv2_sygeplej4x)],\
                        "FT" :\
                       [len(ft_sygeplej1x), len(ft_sygeplej2x), len(ft_sygeplej3x), len(ft_sygeplej4x)]}



table_sygeplej_count = pd.DataFrame(data = dict_sygeplej_count)
display(table_sygeplej_count)
# Out:
#   sygeplej* count in each document   DR   TV2   FT
# 0                    At least once  623  2394  524
# 1                   At least twice  495  1008  296
# 2             At least three times  429   613  211
# 3            More than three times  368   445  156

# %% [markdown]
# In our analysis we will work with articles in which "sygeplej*" appears at least twice.

# %% [markdown]
# Exporting table to latex:

# %%
with open('sygeplej_table.tex','w') as tf:
    tf.write(table_sygeplej_count.to_latex(index=False))

# %% [markdown]
# ### Exploring datasets

# %% [markdown]
# #### 1: Defining function for plotting frequencies of articles:

# %%
def frequency_table(df):
    df['year']=pd.to_datetime(df["date"]).dt.year
    df['month']=pd.to_datetime(df["date"]).dt.month
    df_freq=df.copy()
    df_freq = df_freq.dropna(subset = ['year', 'month'])

    df_freq1, df_freq2, df_freq3, df_freq4=sygeplej_count(df_freq)
    
    freq1 = df_freq1.groupby(['year', 'month'])["content"].count().unstack(fill_value=0).stack()
    
    df_freq1x=pd.DataFrame(freq1).reset_index(drop=False)
    df_freq1x=df_freq1x.rename(columns={0:'content'})
    freq1.reset_index(drop=False)
    
    freq2 = df_freq2.groupby(['year', 'month'])["content"].count().unstack(fill_value=0).stack()
    df_freq2x=pd.DataFrame(freq2).reset_index(drop=True)
    df_freq2x=df_freq2x.rename(columns={0:'content'})

    freq3 = df_freq3.groupby(['year', 'month'])["content"].count().unstack(fill_value=0).stack()
    df_freq3x=pd.DataFrame(freq3).reset_index(drop=True)
    df_freq3x=df_freq3x.rename(columns={0:'content'})
    
    freq4 = df_freq4.groupby(['year', 'month'])["content"].count().unstack(fill_value=0).stack()
    df_freq4x=pd.DataFrame(freq4).reset_index(drop=True)
    df_freq4x=df_freq4x.rename(columns={0:'content'})

    df_freq1x['year']=df_freq1x['year'].astype(str)
    df_freq1x['month']=df_freq1x['month'].astype(str)
    
    df_freq = pd.DataFrame([df_freq1x['year'], df_freq1x['month'], df_freq1x['content'] , df_freq2x['content'],\
                            df_freq3x['content'], df_freq4x['content']]).transpose()
    
    df_freq=df_freq[:-4]
    df_freq.columns=(['Year', "Month","At least once", "At least twice", "At least three times", "More than three times"])
    df_freq['Date']=df_freq['Year']+"-"+ df_freq['Month']
    
    return df_freq

# %% [markdown]
# #### 2: Using Function on datasets

# %%
tv2_freq_df = frequency_table(tv2)
dr_freq_df = frequency_table(dr)
ft_freq_df=frequency_table(ft)

# %% [markdown]
# #### 3: Exploratory plotting
# First, we explore the difference between the different frequency dataframes:

# %% [markdown]
# ##### 3a : TV2

# %%
plt.style.use('ggplot')
sns.set_style("whitegrid")

fig, ax = plt.subplots(nrows=4, ncols=1, sharey=False, figsize=(20,10))
fig.tight_layout(h_pad = 5)
ax[0] = sns.lineplot(x = 'Date', y = "At least once", data=tv2_freq_df, ax=ax[0])
_ = ax[0].set(ylim=(0, 85))
_ = ax[0].set_title("Number of articles mentioning 'sygeplej*' at least once")

ax[1] = sns.lineplot(x = 'Date', y = "At least twice", data=tv2_freq_df, ax=ax[1])
_ = ax[1].set(ylim=(0, 85))
_ = ax[1].set_title("Number of articles mentioning 'sygeplej*' at least twice")

ax[2] = sns.lineplot(x = 'Date', y = "At least three times", data=tv2_freq_df, ax=ax[2])
_ = ax[2].set(ylim=(0, 85))
_ = ax[2].set_title("Number of articles mentioning 'sygeplej*' at least three times")

ax[3] = sns.lineplot(x = 'Date', y = "More than three times", data=tv2_freq_df, ax=ax[3])
_ = ax[3].set(ylim=(0, 85))
_ = ax[3].set_title("Number of articles mentioning 'sygeplej*' more than three times")

_=plt.xticks(rotation=90)

# %% [markdown]
# It seems reasonable to take article in which our search term appears at least twice. The overall tendency is the same but becomes clearer for articles in which the term applies more frequently.

# %% [markdown]
# ##### 3b: DR

# %%
plt.style.use('ggplot')
sns.set_style("whitegrid")

fig, ax = plt.subplots(nrows=4, ncols=1, sharey=False, figsize=(25,10))

ax[0] = sns.lineplot(x = 'Date', y = "At least once", data=dr_freq_df, ax=ax[0])
_ = ax[0].set(ylim=(0, 18))

ax[1] = sns.lineplot(x = 'Date', y = "At least twice", data=dr_freq_df, ax=ax[1])
_ = ax[1].set(ylim=(0, 18))

ax[2] = sns.lineplot(x = 'Date', y = "At least three times", data=dr_freq_df, ax=ax[2])
_ = ax[2].set(ylim=(0, 18))
_=plt.xticks(label=None)

ax[3] = sns.lineplot(x = 'Date', y = "More than three times", data=dr_freq_df, ax=ax[3])
_ = ax[3].set(ylim=(0, 18))

_=plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# We see the same patterns for all articles. This could be explained by the data gathering process. We searched google and got mostly relevant articles. Even though we searched every month, we got more articles for some month and less so for others. In a way, we worked against the search engine. It would be expected that we do not find a pattern because all else equal, the line would be flat. We can reject the hypothesis that there is no development. This is particularly obvious for the corona period.
#
# It is interesting that for DR articles, we see the number of articles peaking at the beginning of corona crisis.

# %% [markdown]
# ##### 3c: Folketinget

# %%
plt.style.use('ggplot')
sns.set_style("whitegrid")

fig, ax = plt.subplots(nrows=4, ncols=1, sharey=False, figsize=(25,10))

ax[0] = sns.lineplot(x = 'Date', y = "At least once", data=ft_freq_df, ax=ax[0])
ax[0].set(ylim=(0, 20))
ax[1] = sns.lineplot(x = 'Date', y = "At least twice", data=ft_freq_df, ax=ax[1])
ax[1].set(ylim=(0, 20))

ax[2] = sns.lineplot(x = 'Date', y = "At least three times", data=ft_freq_df, ax=ax[2])
ax[2].set(ylim=(0, 20))

ax[3] = sns.lineplot(x = 'Date', y = "More than three times", data=ft_freq_df, ax=ax[3])
ax[3].set(ylim=(0, 20))
_=plt.xticks(rotation=90)

# %% [markdown]
# The overall tendency is the same for all four counts of "sygeplej*". It seems that in the second half our period of interest, the term "sygeplejersk*" is generally more frequently used, even if the usage fluctuates quite alot between years.

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Analyzing mentions of "sygeplejersk*" in media and parliament

# %% [markdown]
# #### 1: Plotting number of articles that mention "sygeplejersk*" at least twice by date

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, sharey=False, figsize=(20,10))

sns.lineplot(x = 'Date', y = "At least twice", data=tv2_freq_df, label="TV2")
sns.lineplot(x = 'Date', y = "At least twice", data=dr_freq_df, color="black", label="DR")
sns.lineplot(x = 'Date', y = "At least twice", data=ft_freq_df, color="green", label="Folketinget")

plt.legend(fontsize=15)

_ = plt.title ("Number of DR and TV2 articles and Folketingets agenda items including search term 'sygeplej*' at least twice", fontsize=15)
_ = plt.ylabel("Number of articles")
_ = plt.xticks([0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72, 78, 84, 90, 96, 102, 108, 114, 120, 127])

plt.savefig("sygeplej_twice.pdf", dpi=1200)
plt.show()

# %% [markdown]
# Something is strange in relation to the DR data. After 2021 we cannot find articles that include 'sygeplej' at least once. We checked and looked into an article without finding the term. So it could be that the word does indeed not appear. At least this is the result of the code we run on the articles we have from Jan 2022 and forward. However, this is somewhat surprising and we find this result very surprising against the background of the the development of the frequency curve in the figure. Some DR texts have a different format, so Google links to DR websites but we could not even find the term manually. The sudden stop of the curve is most probably an artefact of the Google search and a change in DR's web infrastructure. At this stage, we continue with the data we have.
#
# Code we used to check the presence of the term 'sygeplej' in articles from 2022:
# ```python
# Checking whether there are articles containing 'sygeplej':
# dr_2022 = dr[(dr["date"].dt.year > 2021)]
# dr_2022_1x = dr_2022[dr_2022['content'].str.count("sygeplej") >= 1]
# dr_2022_1x
#
# ```

# %% [markdown]
# #### 2: Analysis of Tags for DR and TV2

# %% [markdown]
# Defining function to count tags and return count table:

# %%
# Define tag-count function
def tag_count(df):
    df_tags=df["tag"].value_counts()
    df_tags=pd.DataFrame(df_tags).reset_index(drop=False)
    df_tags.columns=("tags", "count")
    return df_tags

# %% [markdown]
# Calling function:

# %%
# Call function
tv2_tags = tag_count(tv2_sygeplej2x)
dr_tags = tag_count(dr_sygeplej2x)

# %% [markdown]
# Plotting 10 most frequent tags

# %%
# Plotting count of tags
plt.style.use('ggplot')
sns.set_style("whitegrid")

fig, ax = plt.subplots(nrows=1, ncols=2, sharey=False, figsize=(15,5))

ax[0] = sns.barplot(x = tv2_tags["tags"][0:10], y = tv2_tags["count"], orient ="v", ax = ax[0])
ax[1] = sns.barplot(x = dr_tags["tags"][0:10], y = dr_tags["count"], orient ="v", ax = ax[1])

_ = ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=45, horizontalalignment='right')
_ = ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=45, horizontalalignment='right')



_ = plt.suptitle("10 Most Frequent Tags", size=20)
_ = ax[0].set_title("TV2")
_ = ax[1].set_title("DR")
_ = ax[0].set_ylabel("Number of Articles")
_ = ax[1].set_ylabel("")

_ = ax[0].set(xlabel=None)
_ = ax[1].set(xlabel=None)
plt.savefig("tags.pdf", dpi=1200)

# %%
tv2_krimi_tag = tv2_analysis[tv2_analysis['tag'] == "Krimi"].copy()

# %%
# Group by year 
tv2_krimi_tag_grouped =  tv2_krimi_tag.groupby(tv2_krimi_tag["date"].dt.year)["tag"].count()

# %%
tv2_krimi_tag_grouped = pd.DataFrame(tv2_krimi_tag_grouped).reset_index()

# %%
# Create and export plot
fig, ax = plt.subplots(nrows=1, ncols=1, sharey=False, figsize=(20,10))
ax = sns.lineplot(x = 'date', y = 'tag', data = tv2_krimi_tag_grouped)\
    .set(title = "Development of the usage of the Tag 'Krimi' in TV2 articles over time", ylabel = "Number of Articles")
plt.savefig("TV2_krimi_tag.jpg", dpi = 1200)

# %%
tv2_krimi_tag_2016 = tv2_krimi_tag[tv2_krimi_tag['date'].dt.year == 2016].copy()
tv2_krimi_tag_2016.sort_values('date', ascending = True, inplace = True)
tv2_krimi_tag_2016

# %%
tv2_krimi_tag_2015 = tv2_krimi_tag[tv2_krimi_tag['date'].dt.year == 2015].copy()
tv2_krimi_tag_2015.sort_values('date', ascending = True, inplace = True)
tv2_krimi_tag_2015
# Out:
#                                                                      titles  \
# 2437                       30-årig sygeplejerske mistænkt for endnu et drab
# 2435                           sygeplejerske sigtet for at dræbe vagns bror
# 2440  sygeplejerske og sosu-assistent dømt: lod livløs mand ligge i havedam
# 2434                     politiet vil ikke sige undskyld til sygeplejersker
# 2439                        sygeplejersker anlægger injuriesag mod anklager
# 2515                  sygeplejersker går rettens vej for at få undskyldning
# 2141                         drabssigtet sygeplejerske skal blive i fængsel
# 2201   sygeplejerske anklaget for sjusk: patient døde efter forkert medicin
# 2583                anklager: drabssag mod sygeplejerske i afsluttende fase
# 2662      drabssigtet sygeplejerske i sms: "jeg har lige taget livet af en"
# 2661                sygehusdrab: landsret tror på beviser mod sygeplejerske
# 2727                   overblik: her er sagen mod drabssigtet sygeplejerske
# 2740                  anklager afviser sygeplejerskes ønske om to advokater
# 2212      advarer mod falske sygeplejersker: ville tage 90-årigs temperatur
#
#      sub_header  \
# 2437        NaN
# 2435        NaN
# 2440        NaN
# 2434        NaN
# 2439        NaN
# 2515        NaN
# 2141        NaN
# 2201        NaN
# 2583        NaN
# 2662        NaN
# 2661        NaN
# 2727        NaN
# 2740        NaN
# 2212        NaN
#
#                                                                                                                                                      h2  \
# 2437                                                                                                                offentligheden vil snart få indblik
# 2435  dette ved vi: nedenfor kan du læse hele live-dækningen, som tv 2's retsreporter janni pedersen, der var til stede under hele retsmødet, stod for.
# 2440                                                                             manden var væk ved hjemmebesøg anklagemyndigheden krævede højere straf
# 2434                                     øverst i artiklen kan du se interviewet med vagn, som ifølge anklagemyndigheden er en af sygeplejerskens ofre.
# 2439                                                                                                     "ikke usædvanligt" kan ikke ignorere udtalelse
# 2515                                                                                                                                                NaN
# 2141                                    fremlagt materiale skal undersøges yderligere omkring 30 nye henvendelser fra borgere om mistænkelige hændelser
# 2201                                                                                                                                 nægter sig skyldig
# 2583                                                                                                                                                NaN
# 2662                                                                                              lider af personlighedsforstyrrelse gav datter medicin
# 2661                                                                                 anklager brugte fire timer forsvarsadvokat: der er tale om sladder
# 2727                                                                                                                                                NaN
# 2740                                                                                                                                et drab blev til to
# 2212                                                                                                                   pas på med at lukke fremmede ind
#
#                                                                                                                                                                                                       content  \
# 2437  nettet om drabsmistænkt sygeplejerske er strammet. den 30-årige sygeplejerske, der er indtil nu var sigtet for tre drab og et drabsforsøg på patienter på nykøbing falster sygehus under en nattevag...
# 2435  - han gad ikke at leve. uanset, hvordan man vender og drejer det. det gjorde han ikke. - jeg har da tænkt på efterfølgende, at hvis hun spurgte, om han har lyst til at komme afsted, så kan det god...
# 2440  en 57-årig sygeplejerske og en 28-årig sosu-assistent er i retten i sønderborg fundet skyldige i grovere skødesløshed ved ikke at have trukket en livløs mand op af en havedam. de er idømt bødestra...
# 2434  anklagemyndigheden afviser ifølge dansk sygeplejeråd at trække en udtalelse tilbage om, at "det ikke er usædvanligt, at sygeplejersker kan finde på at tage livet af patienter." det oplyser grete c...
# 2439  dansk sygeplejeråd har taget kontakt til en advokat for at indlede injuriesag mod den sydsjællandske anklager jeanette w. andersen for hendes kontroversielle udtalelser om sygeplejerskers drab. de...
# 2515  dansk sygeplejeråd indleder nu en injuriesag mod en anklager efter hendes kontroversielle udtalelse om, at "det ikke er usædvanligt, at sygeplejersker kan finde på at tage livet af patienter." det...
# 2727  bevis sygeplejersk tæl sprøjtehylst obduktionserklæring ing så påståed forbryd sygeplejersk nykøbing falst beskyld dræbt fir patient forsøg dræb femt politi bevis ni måned efterforskning stad så s...
# 2740  sag sygeplejersk påståed drab patient nykøbing falst blev så komplek advokat jørg lang læng men klar østr landsr imidlertid afvist anmodning beskik endnu advokat fastslår anklag michael bools mods...
# 2212  årig kvind onsdag sidst uge udsat tricktyveri to falsk sygeplejersk snød kvind hjem ringpark roskild formiddag decemb ringed dør årig uden stod to ung kvind iført sygeplejerskelign uniform fortalt...
#
#                                                                                                                                                                                                      relevant
# 2437                                                                      stram årig sygeplejersk sygeplejersk stram årig indtil sigt tre liv men arbejd oprind sigt dræbt søndag mart klok arbejd årig kvind
# 2435                                                                                                 retsmød frem årig sigt dræbt arn arn herskov årig anhold mart år dag retsmød drabssigted fængsl yder fir
# 2440                                                årig sosuassistent ret bland andr medtiltalt sygeplejersk kom fand andr medtiltalt sygeplejersk kom fand mand vægt underordn forhold sig rik brændgaardni
# 2434                                                         udtal tilbag usædvan kan find tag forbind retsmød såkald ved ret nykøbing gik streg sag sigt fir drab retsmød journalist spurg motiv kom omstrid
# 2439  anders kontroversiel udtal drab oplys dansk tv retsmød sag sygehus nykøbing falst udtalt anklag usædvan kan find tag injuri men anklagemynd fagforening lodr uen græns grov mistænkeliggør sig sygep...
# 2515                                                                                                                           kontroversiel udtal usædvan kan find tag forbind omtalt sag sigt dræbt patient
# 2141       sek måned årig nykøbing falst sid antal dødsfald afdeling åren fald markant sigt sag årig begynd rul kollega kollega forklar politi efterfølg forsøg skjul dø genopliv dag anhold sigt drabsforsøg
# 2201   tiltalt uagtsomt manddrab grov forsøm virk stil næst uge hoft bispebjerg hospital ved fejl gav skriv ekstra blad nægt skyld men patient smertestil medicin valg giv lokalbedøv forårsaged forgiftni...
# 2583                                                                sigt dræbt fler tassing sag årig begynd rul kollega kollega forklar politi efterfølg forsøg skjul dø genopliv dag anhold sigt drabsforsøg
# 2662                                                                                                                       sigt dræbt fler tilfæld lign hinand sigt drab årig frem ved undersøg hår fund spor
# 2661                                                    politi bevis drabs fortsat så god frygted vagt drabssigted tror slår patient patient ihjel husk sagt kollega fler netop dødsfald drab beskyld stå bag
# 2727   tæl sprøjtehylst obduktionserklæring så påståed forbryd nykøbing falst beskyld politi bevis kvind først påståed off mand død så kom gåend gang klar væsk hånd and påståed off februar omkring klok ...
# 2740                         påståed drab patient michael bools modsat plan betal vor anklag ritzau årig forældr beslut gern forlæng sidst ankom ved halvtitid retssal dom vurd mistank begrund såled tirsdag
# 2212                                              tricktyveri to falsk snød kvind hjem ung kvind iført uniform fortalt mål roskild lykked falsk tøm kvind smykkeskrin uniform oplysning falsk kan kontak midt

# %%
tv2_krimi_tag_2012 = tv2_krimi_tag[tv2_krimi_tag['date'].dt.year == 2012].copy()
tv2_krimi_tag_2012.sort_values('date', ascending = True, inplace = True)
tv2_krimi_tag_2012
# Out:
#                                               titles sub_header  \
# 118             sygeplejeråd: nej til øget sikkerhed        NaN
# 98                  knivmand ville ikke have medicin        NaN
# 106                      fyns politi: vi har god tid        NaN
# 96                  tre knivofre fra ouh er opereret        NaN
# 107                 ofre for knivmand stadig indlagt        NaN
# 83                 sigtes for tredobbelt drabsforsøg        NaN
# 113                ouh-knivstikker fængslet i 4 uger        NaN
# 123           sigtet: jeg havde kniven med hjemmefra        NaN
# 139                frivillig sex skader som voldtægt        NaN
# 115                    læge udskrives efter knivstik        NaN
# 420       blodproppatient flygtede under ouh-optøjer        NaN
# 426  dramaet på ouh: sådan jagtede bøller skud-offer        NaN
# 693               mand kræves anbragt efter overfald        NaN
#
#                                                                                                                                                                                                           h2  \
# 118                                                                                                                                                   uddannelse skaber sikkerhed lægens tilstand er kritisk
# 98                                                                                                                                                                                         fik fat i en kniv
# 106                                                                                                                                                                                                      NaN
# 96                                                                                                                                                    angreb pludseligt med kniv ville ikke tage sin medicin
# 107                                                                                                                                            brugte skumslukker ved anholdelse uvist hvor kniv stammer fra
# 83                                                                                                                                                                                                       NaN
# 113                                                                                                                                                                        sigtet var ikke meget for at tale
# 123                                                                                                                                                                                                      NaN
# 139                                                                                                                                                                                                      NaN
# 115                                                                                                                                  var frustreret over tvangsindlæggelse sjuskede og uklare retningslinjer
# 420                                                                                                                                                                                                      NaN
# 426  flere skudt i vollsmose kendte godt konsekvenserne mellem 60-70 'bøller' yderdørene blev lukket -dørene åbnet aktivt i dag låser dørene automatisk klar til operation valgte at trække tjenestepisto...
# 693                                                                                                                                                                 havde stålwire og sten med på hospitalet
#
#                                                                                                                                                                                                      content  \
# 118  der skal ikke indsættes sikkerhedsvagter på landets psykiatriske afdelinger for at undgå episoder som den i odense, hvor tre hospitalsansatte er blevet udsat for et knivoverfald. sådan lyder meldi...
# 98   den 47-årige psykiatriske patient, der i formiddags stak en læge og to sygeplejersker ned på odense universitetshospital, gik amok i forbindelse med, at han skulle have sin medicin. det oplyser læ...
# 106  fyns politi giver sig god tid for at undgå en voldelig anholdelse af en 47-årig psykisk syg mand, der i dag stak tre ansatte ned på den lukkede psykiatriske afdeling på odense universitetshospital...
# 96   de tre ansatte på psykiatrisk afdeling, der tidligere i dag blev overfaldet af en patient med en kniv, er nu blevet opereret. "operationerne gik godt," siger direktør jens peter steensen fra odens...
# 107  en læge og to sygeplejesker fra odense universitets hospital er fortsat indlagt, efter en psykisk syg mand i går morges overfaldt dem på hospita-lets lukkede psykiatriske afdeling. gerningsmanden ...
# 83   en 47-årig psykisk syg mand, der i går blev anholdt efter at have stukket en læge og to sygeplejersker ned på odense universitetshospital, sigtes af politiet for tredobbelt drabsforsøg, når han kl...
# 113  den 47-årige psykisk syge mand, der i går overfaldt en læge og to sygeplejer-sker på odense universitetshospital, er blevet varetægtsfængslet i fire uger på en psykiatrisk afdeling og skal desuden...
# 123  den 47-årige mand, der er sigtet for knivoverfaldene på en 34-årig læge og to sygeplejersker, sagde i dag i ret-ten, at han havde taget gerningsvåbnet med hjemmefra i sin taske. det har hidtil vær...
# 420         https://nyheder.tv2.dk/krimi/2012-08-28-blodproppatient-flygtede-under-ouhoptoejer
# 426  https://nyheder.tv2.dk/krimi/2012-12-12-dramaet-paa-ouh-saadan-jagtede-boeller-skud-offer
# 693                https://nyheder.tv2.dk/krimi/2012-12-20-mand-kraeves-anbragt-efter-overfald
#
#     source  \
# 118    tv2
# 98     tv2
# 106    tv2
# 96     tv2
# 107    tv2
# 83     tv2
# 113    tv2
# 123    tv2
# 139    tv2
# 115    tv2
# 420    tv2
# 426    tv2
# 693    tv2
#
#                                                                                                                                                                                              content_cleaned  \
# 118  der skal ikke indsættes sikkerhedsvagter på landets psykiatriske afdelinger for at undgå episoder som den i odense hvor tre hospitalsansatte er blevet udsat for et knivoverfald sådan lyder melding...
# 98   den årige psykiatriske patient der i formiddags stak en læge og to sygeplejersker ned på odense universitetshospital gik amok i forbindelse med at han skulle have sin medicin det oplyser lægefagli...
# 106  fyns politi giver sig god tid for at undgå en voldelig anholdelse af en årig psykisk syg mand der i dag stak tre ansatte ned på den lukkede psykiatriske afdeling på odense universitetshospital to ...
# 96   de tre ansatte på psykiatrisk afdeling der tidligere i dag blev overfaldet af en patient med en kniv er nu blevet opereret operationerne gik godt siger direktør jens peter steensen fra odense univ...
# 107  en læge og to sygeplejesker fra odense universitets hospital er fortsat indlagt efter en psykisk syg mand i går morges overfaldt dem på hospitalets lukkede psykiatriske afdeling gerningsmanden var...
# 83   en årig psykisk syg mand der i går blev anholdt efter at have stukket en læge og to sygeplejersker ned på odense universitetshospital sigtes af politiet for tredobbelt drabsforsøg når han klokken ...
# 113  den årige psykisk syge mand der i går overfaldt en læge og to sygeplejersker på odense universitetshospital er blevet varetægtsfængslet i fire uger på en psykiatrisk afdeling og skal desuden menta...
# 123  den årige mand der er sigtet for knivoverfaldene på en årig læge og to sygeplejersker sagde i dag i retten at han havde taget gerningsvåbnet med hjemmefra i sin taske det har hidtil været en gåde ...
# 139  når politifolk rundt om i verden efterforsker en voldtægtssag skeler de til om en undersøgelse af kvindens underliv afslører rifter eller mærker i skeden det betragtes som tegn på at der er sket e...
# 115  den årige læge som for to uger siden blev stukket ned af en psykisk syg patient i odense og var i livsfare er nu i hastig bedring han udskrives snart fra hospitalet og følger dermed i fodsporet på...
# 420  da til aggressive mænd i sidste uge stormede skadestuen på odense universitetshospital flygtede en blodproppatient i panik op på førstesal for at komme væk fra tumulten og det bragte patienten i l...
# 426  klokken var omkring tirsdag august da et stort antal vrede bevæbnede mænd ifølge fyns politi mellem og  forsamlede sig uden for skadestuen på odense universitetshospital ouh mindre end en time for...
# 693  anklagemyndigheden kræver en årig mand anbragt på sikringsanstalten i nykøbing sjælland fordi han har forsøgt at dræbe en læge og to sygeplejersker det fremgår af anklageskriftet mod manden som ri...
#
#                                                                                                                                                                                                content_prepr  \
# 118  indsæt sikkerhedsvag land psykiatrisk afdeling undgå episod odens tre hospitalsansat blev udsat knivoverfald lyd melding dansk sygeplejeråd følg situation odens tæt nej syn bestemt vagt afdeling n...
# 123                                                                                                                                               årig læg to sagd dag ret fik blotlag tarm fået snitsår ene
# 139                                                                                                                                                                   voldtægtsofr ene sid afslør nem frivil
# 115                                                                                                                      dermed fodspor to overfald psykiatrisk afdeling overfald læg to indsmugl kniv angiv
# 420                                                                                                                                           trap sket sam ved tid afhøring tid frem flygt måsk redded mand
# 426                                                                               ivan peters via person vej råbt aft nem fir telefon forsøg oversygeplejersk sygeplejersk telefon forsøg len wichman vejled
# 693                                                                                                      dræb læg to fremgår anklageskrift mand bryst hals ene stuk fir gang gang brystkas men bland and fik

# %% [markdown]
# # Sygeplejerske tiltalt for drab-tag

# %%
tv2_drab_tag = tv2_analysis[tv2_analysis['tag'] == 'Sygeplejerske tiltalt for drab'].copy()
tv2_drab_tag

# %%
tv2_drab_tag
# Out:
#                                                                                                titles  \
# 2859                              drabstiltalt sygeplejerske i retten: stirrer stift på sin forsvarer
# 2862              drabstiltalt sygeplejerske offentliggør 12 sider langt brev: har lyst til at skrige
# 2864                                              fakta: sygeplejerske er tiltalt for ni forbrydelser
# 2865                                                    drabstiltalt sygeplejerske nægter sig skyldig
# 2866                                drabstiltalt sygeplejerske: - var som om dødsfaldene kom i bølger
# 2867                        faders vidneudsagn fik sygeplejerske til at bryde sammen i tårer i retten
# 2872                                                             12-talspige og tiltalt for seriemord
# 2917                 poul madsen i modvind i presselogen: viser billede af drabstiltalt sygeplejerske
# 2924                   fik sms'er om dødsfald fra kæresten: da natten var omme var tre patienter døde
# 2963                                            kolleger roser drabstiltalt sygeplejerske til skyerne
# 3015                                           dommen er faldet: 31-årig sygeplejerske skyldig i drab
# 3016                                           lokale om tredobbelt drabssag: - det her er en grim én
# 3027                                                   31-årig sygeplejerske idømt fængsel på livstid
# 3032                                anklager går efter fængsel på livstid: tiltalte var en dødsdjævel
# 3482  for første gang står forældrene til drabsdømt sygeplejerske frem: - vi har aldrig været i tvivl
# 3483                                            pårørende står frem: - hvorfor dræbte hun min farfar?
#
#                                                                                                                                                   sub_header  \
# 2859  det er en tydelig tynget sygeplejerske, der fredag sidder tiltalt for tre drab og drabsforsøg i retten i nykøbing falster. kvinden nægter sig skyldig.
# 2862       - uvisheden er i sig selv så angstskabende, at den nærmest overtager alle tanker i mit hoved, skriver den drabstiltalte sygeplejerske til tv øst.
# 2864                                                            ud over tre drab og et drabsforsøg tæller anklageskrift mod sygeplejerske fem andre forhold.
# 2865                       sygeplejersken fra nykøbing falster sygehus, der er tiltalt for tre drab og et drabsforsøg fastholdt mandag, at hun var uskyldig.
# 2866                                          arbejdsmiljøet på nykøbing falster sygehus var ofte under pres, fortæller drabstiltalt sygeplejerske i retten.
# 2867   på fjerdedagen var det de allernærmeste pårørende, faderen og kæresten til den drabstiltalte 31-årige sygeplejerske der blev afhørt. her er overblik.
# 2872                                                         retssag mod sygeplejerske fra nykøbing falster røber store hemmeligheder fra den tiltaltes liv.
# 2917    ekstra bladet har valgt at offentliggøre navn og billede på den tiltale i den såkaldte sygeplejerske-sag. en klar fejl, mener de øvrige mediechefer.
# 3483                                https://nyheder.tv2.dk/krimi/2017-03-01-paaroerende-staar-frem-hvorfor-draebte-hun-min-farfar
#
#      source  \
# 2859    tv2
# 2862    tv2
# 2864    tv2
# 2865    tv2
# 2866    tv2
# 2867    tv2
# 2872    tv2
# 2917    tv2
# 2924    tv2
# 2963    tv2
# 3015    tv2
# 3016    tv2
# 3027    tv2
# 3032    tv2
# 3482    tv2
# 3483    tv2
#
#                                                                                                                                                                                               content_cleaned  \
# 2859  hun er tiltalt for tre patientdrab og et drabsforsøg men nægter selv alt den tiltalte årige sygeplejerske i sagenom sygehusdrab i nykøbing falster sidder fredag på bænken i retten hvor huner tydel...
# 2862  en sygeplejerske som er tiltalt for at have dræbt tre patienter og for at have forsøgt at dræbe en fjerde på sygehus i nykøbing falster har udgivet et sider langt brev som hun har sendt til tv øst...
# 2864  retten i nykøbing falster indleder fredag retssagen mod en sygeplejerske der marts blev anholdt efter en nattevagt på det lokale sygehus hvor flere patienter døde i alt er den årige kvinde tiltalt...
# 2865  den årige sygeplejerske der er tiltalt for tre drab og et drabsforsøg mod patienter på nykøbing falster sygehus fastholdt mandag at hun ikke har givet patienterne medicin i en dødelig dosis hun næ...
# 2866  ofte var der på nykøbing falster sygehus flere patienter end personalet kunne klare og samtidig gjorde læger fra udlandet det svært for personalet at kommunikere det fortalte en årig sygeplejerske...
# 2867  på fjerdedagen i den over dage lange retssag mod den drabstiltalte årige sygeplejerske var det nogle af de allernærmeste pårørende der skulle vidne i sagen den årige sygeplejerske der er tiltalt f...
# 2872  det var et job som ufaglært medhjælper på et plejehjem der gjorde udslaget den unge hfstudent ville være sygeplejerske og derfor søgte hun i eller om optagelse på sygeplejeskolen i herlev dengang ...
# 2917  presselogen sætter med danske mediechefer i studiet og en newsvært kritisk fokus på pressens dækning af ugens tophistorier for mediecheferne bliver der også tid til at erkende sine journalistiske ...
# 2924  en overlæge på sygehuset i nykøbing falster fik i løbet af vinteren mistanke om at en årig sygeplejerske gjorde skade på patienteri første omgang kom mistanken fra hans samlever der som sygeplejer...
# 2963  det kan godt være at hun er tiltalt for at slå patienter ihjel men først og fremmest er hun en dygtig ambitiøs og pligtopfyldende sygeplejerske og et sympatisk menneske efter hele retsmøder i drab...
# 3015  den årige sygeplejerske fra nykøbing falster sygehus er fundetskyldig i at have begået tre drab på patientersamt et drabsforsøg hun findes skyldig i punkt  og og der handler om manddrab ogforsøg p...
# 3016  det er ikke hver dag at en tredobbelt drabssag rydder forsiderne på landets aviser ikke desto mindre skete det da en af danmarkshistoriens mest spektakulære drabssager udfoldede sig inykøbing fals...
# 3027  retsformandhenrik lindeidømmer den årige sygeplejerske christinahansenfængsel på livstid anklager michael boolsen er tilfreds med dommen på livstid til den årig sygeplejerske der er dømt for tre d...
# 3032  den årige sygeplejerske fra nykøbing falster sygehus er fundet skyldig i tre drab og et drabsforsøg anklager michael boolsen går efter fængsel på livstid der er tale om inkompetent pasning af pati...
# 3482  christina hansener dømt for at tage livet af flere patienter på nykøbing falster sygehus men selvom hun er idømt livstid så tvivler hendes familie ikke på hendes uskyld i aften står de frem i stat...
# %%
fig, ax = plt.subplots(nrows=1, ncols=1, sharey=False, figsize=(20,10))

sns.lineplot(x = 'month', y = 'search_results', data = dr_google_search_results)

_ = plt.title ("Development of number of DR articles results for Google search for sygeplej* and month year combination", fontsize = 18)
_ = plt.ylabel("Number of articles")
_ = plt.xticks([0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72, 78, 84, 90, 96, 102, 108, 114, 120, 127])
_ = plt.xticks(rotation=45)


plt.savefig("DR_sygeplej_searches.pdf", dpi=1200)
plt.show()
# Out:
# 75

# %%
tv2_krimi_tag = tv2_krimi_tag.dropna(subset = ['titles'])

# %%
tv2_krimi_tag = tv2_krimi_tag[tv2_corona_tag['titles'].str.contains("sygepl")]
# Out:
# C:\Users\jgb569\AppData\Local\Temp/ipykernel_17548/2880682714.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tv2_krimi_tag = tv2_krimi_tag[tv2_corona_tag['titles'].str.contains("sygepl")]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17548/2880682714.py in <module>
# ----> 1 tv2_krimi_tag = tv2_krimi_tag[tv2_corona_tag['titles'].str.contains("sygepl")]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3447         # Do we have a (boolean) 1d indexer?
#    3448         if com.is_bool_indexer(key):
# -> 3449             return self._getitem_bool_array(key)
#    3450
#    3451         # We are left with two options: a single key, and a collection of keys,
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3500         # check_bool_indexer will throw exception if Series key cannot
#    3501         # be reindexed to match DataFrame rows
# -> 3502         key = check_bool_indexer(self.index, key)
#    3503         indexer = key.nonzero()[0]
#    3504         return self._take_with_is_copy(indexer, axis=0)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2386         mask = isna(result._values)
#    2387         if mask.any():
# -> 2388             raise IndexingError(
#    2389                 "Unalignable boolean Series provided as "
#    2390                 "indexer (index of the boolean Series and of "
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
pd.options.display.max_colwidth = 200
tv2_krimi_tag
# Out:
#                                                                                                               titles  \
# 5129                                  kunstig intelligens skal overvåge corona-patienter i stedet for sygeplejersker
# 5133                                      italien kæmper hårdt mod coronavirus - sygeplejerske viser blå mærker frem
# 5140                                  hundredvis af sygeplejersker opkvalificeres for at kunne passe coronapatienter
# 5141                                                    sygeplejersker i usa advarer om mangelfuld virusforberedelse
# 5142              sverige ser største stigning i dødsfald hidtil - flere læger og sygeplejersker indlagt på intensiv
# 5218                       sygeplejerske deler patients sidste ord inden respirator: - hvem skal betale for det her?
# 5223               sygeplejersker i usa sendt hjem, efter de nægtede at behandlecorona-patienter uden særlige masker
# 5226                               enhedslisten vil give sosu'er og sygeplejersker 1700 kroner mere i løn om måneden
# 5301                                             læger og sygeplejersker vender ryggen til premierminister i protest
# 5518                                    sygeplejersker kræver handlingsplan - flere har tunge senfølger efter corona
# 5600                                                 danmark gør klar til vaccine: søger tandlæger og sygeplejersker
# 5601                                                       kontant bonus på vej til endnu flere jyske sygeplejersker
# 5726                                 830 sygehusansatte smittet – overlæger og sygeplejersker kommer med hård kritik
# 5729  stigende smitte fører til aflyste operationer på stribe - nu sender læger og sygeplejersker bøn til regeringen
# 5732                                                fik honningkager som tak – nu leverer sygeplejersker dem tilbage
# 5734                                          sygeplejersker stadig hårdt ramt af coronavirus: - det er frustrerende
# 5742                                                    region giver bonus på op til 15.000 til coronasygeplejersker
# 5823                       hver anden franskmand vil ikke vaccineres: jeg har ikke brug for det, siger sygeplejerske
# 5861                                          et sydafrikansk studie tyder på, at vaccinen fra astrazeneca har nedsat effekt mod den sydafrikanske mutation.
# 5862                            overlæge og virolog ved statens serum institut mener, at man skal takke ja, hvis man er så heldig at blive tilbudt vaccinen.
# 5896                                            et år efter at who erklærede covid-19 for en pandemi, er sygeplejersker mange steder udbrændte, advarer råd.
# 5898                selv om sygeplejersker og social- og sundhedsassistenter i højere grad skulle vaccineres end læger, kommerlægerne forrest i vaccinekøen.
# 5900                                           en række europæiske lande vil ligesom danmark have undersøgt corona-vaccinen fra astrazeneca lidt grundigere.
# 5934                           lægemiddelstyrelsen har behandlet 27 indberetninger om blodpropper blandt personer, der er blevet vaccineret med astrazeneca.
# 5976      sygeplejerskerne kan ikke blive ved med at yde en ekstra indsats, lyder det fra dsr. politiker kalder frederiksens appel for "vildt provokerende".
# 5978                                          fjendtlighed og trusler er et voksende problem under coronapandemien, fortæller formand for tysk lægeforening.
# 6128           anne-marie larsen blev smittet med corona, efter hun blev flyttet til en corona-afdeling. nu har regionen fyret hende på grund af sygefravær.
# 6434     en gruppe sygeplejersker vendte trodsigt ryggen til statsministeren, da hun trådte på scenen. "nej. lev med det", stod der bagpå deres røde trøjer.
# 6513                      sundhedsøkonom jes søgaard har for tv 2 lavet beregninger for en vinterpakke til sygehusene på mellem én og tre milliarder kroner.
# 6579          det pædagogiske personale har højere positivprocent end sundhedspersonalet. fagforening ønsker mulighed for at sende børn hjem ved høj smitte.
#
#                                                                                                                                                                                                            h2  \
# 5129                               tages i brug på mandag fanger 20 gange så mange faresignaler kunstig intelligens frasorterer falske alarmer mindre berøring men mere omsorg.  tilpasset corona på få uger
# 5133                                                                                              45 i respirator med coronavirus 'en katastrofe' ældre patienter dør så sin døde far lægernes kamp mod tiden
# 5140                                                                                                                                                                  tør ikke håbe på noget kapaciteten øges
# 5141                                                                                                                                                                "virkelig foruroligende" tilbagemeldinger
# 5142                                                                                                                                            patienter risikerer at dø arbejde mod tredobling af kapacitet
# 5218                                                                                         dybt indtryk "vi har fejlet" hvad koster en covid-19-behandling i usa? hvor meget skal amerikanerne selv betale?
# 5223                                                                                                                                                             en kollega blev smittet politikken er ændret
# 5226                                                                                                                                                                       parterne skal selv fordele pengene
# 5301                                                                                                                                             - som et slag i ansigtet hospitalsdirektør bakker ansatte op
# 5518                                                                                                                                                  koncentrationsbesvær og træthed opfordring til ministre
# 5600                                                                                                                                                                i odense kan pensionister søge stillingen
# 5601                                                                                                      aftale giver kontant bonus mange sygeplejersker er sendt hjem sygeplejersker frygter en slem vinter
# 5726  masker giver sår om munden og vejrtrækningsproblemer - hvis man har lidt barm og bag, passer kitlerne ikke danske regioner kan ikke genkende kritikken professor: værnemidlerne virker, men smitte k...
# 5729                                                                                                                                         sundhedsmedarbejdere: suspender ordningen ssi: bekymrende udsigt
# 5732                                    giver hjerter tilbage - det er følelsen af, at det var det, vi var værd region hovedstaden: - det faldt ikke i god jord andre regioner takker med kontante bonusser
# 5734                                                                                                                          forhandlinger om covid-pukkel stort pres på afdelingerne syddanmark giver bonus
# 6128                     https://nyheder.tv2.dk/samfund/2021-07-23-sygeplejerske-med-corona-senfoelger-fyret-af-region-sjaelland
# 6434      https://nyheder.tv2.dk/samfund/2021-11-10-sygeplejersker-sendte-bestemt-budskab-til-mette-frederiksen-paa-vaelgermoede
# 6513              https://nyheder.tv2.dk/samfund/2021-12-02-saadan-kan-milliarderne-til-sygehuse-og-sygeplejerskerne-fordele-sig
# 6579     https://nyheder.tv2.dk/samfund/2022-01-04-paedagogers-positivprocent-er-fire-gange-hoejere-end-sygeplejerskers-og-de-er
#
#      source  \
# 5129    tv2
# 5133    tv2
# 5140    tv2
# 5141    tv2
# 5142    tv2
# 5218    tv2
# 5223    tv2
# 5226    tv2
# 5301    tv2
# 5518    tv2
# 5600    tv2
# 5601    tv2
# 5726    tv2
# 5729    tv2
# 5732    tv2
# 5734    tv2
# 5742    tv2
# 5823    tv2
# 5861    tv2
# 5862    tv2
# 5896    tv2
# 5898    tv2
# 5900    tv2
# 5934    tv2
# 5976    tv2
# 5978    tv2
# 6128    tv2
# 6434    tv2
# 6513    tv2
# 6579    tv2
#
#                                                                                                                                                                                               content_cleaned  \
# 5129  der er travlt på de danske sygehuse med stadigt flere indlagte coronapatienter og mangel på både værnemidler og personale er landets læger og sygeplejersker under et alvorligt pres men heldigvis e...
# 5133  hun har blå mærker i ansigtet efter alt for mange timers arbejde iført en plastikmaske med åndedrætsværn kvinden hedder alessia bonari hun er sygeplejerske og bange for at gå på arbejde fordi hver...
# 5140  på fem dage er antallet af indlagte coronapatienter på de danske hospitaler steget fra til på intensivafdelinger er det gået fra to til  af dem er i respirator sundhedsvæsnet er under pres men kan...
# 5141  den største sygeplejerskefagforening i usa advarer om foruroligende mangel på forberedelser til udbruddet af coronavirus på mange hospitaler og klinikker sygeplejerskerne mangler nødvendigt beskyt...
# 5142   personer har mistet livet som følge af covid i stockholm men coronavirussens spredning rammer nu også det personale som skal redde liv i det der af svenske sundhedsmyndigheder bliver kaldt en sto...
# 5218   de var hans sidste ord og jeg vil aldrig glemme dem det siger anæstesisygeplejerske derrick smit til cnn derrick smit arbejder med covid patienter på et hospital i byen new york som er hårdt ramt...
# 5223  ti sygeplejersker fra et hospital i den amerikanske delstat californien er blevet tvunget på orlov fordi de nægtede at behandle covidpatienter hvis ikke de fik udleveret særlige masker det skriver...
# 5226  personalet i det sundhedsfaglige coronaberedskab på de danske hospitaler og plejehjem skal have en løn der afspejler den indsats de leverer i øjeblikket det mener enhedslisten der foreslår at afsæ...
# 5301  i belgien fik premierminister sophie wilmès en kold modtagelse da hun lørdag besøgte saint pierrehospitalet i hovedstaden bruxelles som er det hospital der har behandlet flest patienter med corona...
# 5518  der er brug for en national plan for opfølgning på og behandling af senfølger efter covid det mener formand for dansk sygeplejeråd grete christensen mange af vores medlemmer går rundt med tunge se...
# 5600  de første danskere ventes at kunne blive vaccineret i starten af det nye år og i den forbindelse er sundhedsmyndighederne ved at skaffe personale til at stå for vaccinationerne region hovedstaden ...
# 5601  sygeplejersker i region midtjylland anerkendes kontant nu for det arbejde de har udført og kommer til at udføre mere af under coronapandemien det sker med aftaler som anja laursen der er formand f...
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           gang uden lighus skriv cnn ubarmhjert ubarmhjert sig claudiu ionita bucharest university hospital lig pres helt bund rumæni fjerd coronabølg and sted hospital nyl udvided intensivafdeling seng nær én optag ved skift sengetøj ene led seng person lå lig lighus

# %%
# Out:
# 108

# %% [markdown]
# #### 3: Plotting google searches for sygeplej* on DR

# %%
dr_google_search_results
# Out:
#      search_results      month
# 0              2220  jan. 2012
# 1              1450  feb. 2012
# 2              1360  mar. 2012
# 3              1310  apr. 2012
# 4              1700   maj 2012
# ..              ...        ...
# 123            1160  apr. 2022
# 124           10600   maj 2022
# 125              22  jun. 2022
# 126             423  jul. 2022
# 127            3030  aug. 2022
#
# [128 rows x 2 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, sharey=False, figsize=(20,10))

sns.lineplot(x = 'month', y = 'search_results', data = dr_google_search_results)

_ = plt.title ("Development of number of DR articles results for Google search for sygeplej* and month year combination", fontsize = 18)
_ = plt.ylabel("Number of articles")
_ = plt.xticks([0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72, 78, 84, 90, 96, 102, 108, 114, 120, 127])
_ = plt.xticks(rotation=45)


plt.savefig("DR_sygeplej_searches.pdf", dpi=1200)
plt.show()

# %%
dr_google_search_results = dr_google_search_results.sort_values('search_results', ascending = False)
dr_google_search_results.head(5)
# Out:
#      search_results      month
# 100           11600   maj 2020
# 124           10600   maj 2022
# 112            9220   maj 2021
# 127            3030  aug. 2022
# 122            2780  mar. 2022

# %%
with open('dr_months_most_searches_sygeplej.tex','w') as tf:
    tf.write(dr_google_search_results.head(5).to_latex(index=False))
with open('dr_months_least_searches_sygeplej.tex','w') as tf:
    tf.write(dr_google_search_results.tail(5).to_latex(index=False))

# %% [markdown]
# ### Preparing documents

# %% [markdown]
# #### 1: Removing unnecessary characters

# %%
def analysis_cleaner(document):
    document = re.sub(r'[^\w\s]', '', document) #Remove non-alphanumeric characters
    document = re.sub(r'[^\D+]', '', document) #Remove non-numberic characters
    document = document.replace(r'\W', ' ')\
                .replace('  ', ' ')
    return document

# %%
dr_analysis = dr_sygeplej2x.copy()
tv2_analysis = tv2_sygeplej2x.copy()
ft_analysis = ft_sygeplej2x.copy()

dr_analysis["content_cleaned"] = dr_analysis["content"].apply(analysis_cleaner)
tv2_analysis["content_cleaned"] = tv2_analysis["content"].apply(analysis_cleaner)
ft_analysis["content_cleaned"] = ft_analysis["content"].apply(analysis_cleaner)

# %% [markdown]
# #### 3: Add preprocess column

# %% [markdown]
# Define function:

# %%
def pre_process(document):
    stemmer = SnowballStemmer("danish")
    danish_stopwords=stopwords.words("danish")
    
    document = nltk.tokenize.word_tokenize(document) # tokenize
    document = [word for word in document if not word in danish_stopwords] # delete stopwords
    document = [stemmer.stem(word) for word in document] # all stemmed words in a list
    document =' '.join(document) # joining stemmed words
    return document

# %% [markdown]
# Run function on datasets to create a conten_cleaned column:

# %%
dr_analysis["content_prepr"] = dr_analysis["content_cleaned"].apply(pre_process)
tv2_analysis["content_prepr"] = tv2_analysis["content_cleaned"].apply(pre_process)
ft_analysis["content_prepr"] = ft_analysis["content_cleaned"].apply(pre_process)

# %% [markdown]
# #### 4: Add a column with words within n words of sygeplejsk* in documents

# %% [markdown]
# Defining a function that returns the sorrounding n words for a given word:

# %%
def extract_surround_words_BetterRead(text, keyword, n):
    '''
    text : input text
    keyword : the search keyword we are looking
    n : number of words around the keyword
    '''
    surround_words=[]
    #extracting all the words from text
    words = re.findall(r'\w+', text)
    
    #iterate through all the words
    for index, word in enumerate(words):

        #check if search keyword matches
        if keyword in word:
            #fetch left side words
            left_side_words = words[index-n : index]
            
            #fetch right side words
            right_side_words = words[index+1 : index + n + 1]
            
            surround_words.append(left_side_words + keyword)
            surround_words.append(right_side_words)
    return surround_words

# %% [markdown]
# Defining a function that creates a new column with extract_surround_words function for our three datasets:

# %%
def find_relevant_BetterRead(df, word, n):
    r=[]
    for row in df["content_cleaned"]:
        temp= extract_surround_words_BetterRead(row, word, n)
        temp_list=[]
        for i in temp:
            stems=' '.join(i)
            temp_list.append(stems)
            s=" ".join(temp_list)
        r.append(s)
    df['relevant_text']=r
    return df

# %%
dr_analysis
# Out:
#                                                                                                   titles  \
# 0                                                                  danske sygeplejersker får job i norge
# 1                                                                     næsten ingen ledige sygeplejersker
# 5                                                        regionsformand: jeg har ikke noget at undskylde
# 14                                                                sygeplejersker vil skære i nattevagter
# 15                                                              udenlandske sygeplejersker er taget hjem
# ...                                                                                                  ...
# 1495            læger og sygeplejersker siger stop: 'kan ikke være den sygeplejerske jeg gerne vil være'
# 1496                detektor: talsperson erkender - har ikke tal på påstand om døde patienter på gangene
# 1497     flere sygeplejersker skifter til det private: 'nu får jeg en løn, der matcher mine kompetencer'
# 1498   nu skal sygeplejersker og læger fra hospitaler ud at vaccinere, og det kan gå ud over operationer
# 1499  'det skal være normen at være på fuldtid': men hver anden sygeplejerske arbejder lige nu på deltid
#
#                                                                                                                  sub_header  \
# 0                             krise, fyringer og ansættelsesstop får sygeplejerskerne til at tage til norge for at arbejde.
# 1                                    trods fyringsrunder i både 2010 og 2011 er arbejdsløsheden på 1 pct. i region sjælland
# 5                                  steen bach nielsen forstår ikke, at sygeplejersker kan føle deres ytringsfrihed krænket.
# 14             risiko for at natarbejde er kræftfremkaldende får sygeplejerskerne til at kræve højst to nattevagter i træk.
# 15                                           det er slut med sygeplejerudtryk på gebrokkent dansk på de nordjyske sygehuse.
# ...                                                                                                                     ...
# 1495                                      ifølge ansatte på holbæk sygehus, så er forholdene nu så dårlige, at de siger op.
# 1496  talsperson for opsigelser blandt sygeplejersker luca pristed fortæller, at han vil formulere sig anderledes fremover.
# 1497                             der skal gøres noget ved løn og vilkår i det offentlige, lyder det fra dansk sygeplejeråd.
# 1498                                              i både region midtjylland og region syddanmark lånes hospitalsansatte ud.
# 1499             regionshospitalet randers kunne få timer svarende til 26 årsværk, hvis alle sygeplejersker gik på fuldtid.
#
#                                                                                                                                                                   h2  \
# 0                                                                                                                                                      markant flere
# 1                                                                                                                                                                NaN
# 5                                                                                                                                                                NaN
# 14                                                                                                                        færre nattevagter fast døgnrytme er vigtig
# 15                                                                                                                                                               NaN
# ...                                                                                                                                                              ...
# 1495                                                                                                                            besøg fra arbejdstilsynet klare krav
# 1496  debatindlæg som dokumenation sundhedsøkonom: 'ude på et overdrev' ingen data om døde på gangene 80 fortællinger fra facebook overdrivelser kan skabe problemer
# 1497                                                                                    fik hjertebanken sygeplejerskerne siger fra ’ikke et problem for regionerne’
# 1498                                                                                                                      frygter længere ventelister ansætter mange
# 1499                                                                                       fuldtidsstrategi enormt potentiale sygeplejerske: arbejdspresset skal ned
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1495                                                                                                                                                                                                                                                                                                             flygt region sjælland sign fuglesang lars vend erhverv ryg ryg plejed arbejd medicinsk afdeling holbæk vilkår gør kan gern arbejd sted tandklinikassistent uddanned før hverdag anderled løn klar krav træk igen bedr arbejdsvilkår priorit hvilk opgav nå arbejd mul
# 1496                                                                                                                                                                                                                                                                                                                                                          sundhedsvæs luca pristed talsmand national grup grup arbejdsnedlæg opfordr sig protest dår pristed fler grup facebook oplev patient skrev opslag facebookgrup mer værd luca sundhedsvæs sat men talsperson tilføj fremov
# 1497  bedr arbejdstid fik camilla ros hans ros hans fler vælg skift job arbejded procent land privat virksom sidst måned tid sid søgt job privat offent sundhedsvæs hver sig cirka tre hans lang enest skift privat grund sygeplejeråd gret christens bar gåend utilfreds vilkår mist dygt offent ansæt find rigt god gedign års erfaring hold gret christens handl søg privat sektor ser vækst antal båd privat offent understreg stad mangel skyld situation lig haft ansat så vor hospital alligevel hospital alligevel mangl and personal simpelth gør mer ansæt and vigt personal
# 1498                                                                                                                                                                                                                                                                                                                                                                                                                                                               sted tag læg stud dag arbejd odens universitetshospitalt primært udlånt læg fortæl udlånt læg fortæl san thil eriks
# 1499                                                                                                            arbejdsug kun procent rand ansat fuldtid kombin generel mangel grad pres sygehus pres sygehus novemb regionshospital rand ubesat sundhedsfag hænd herund overhoved kan få lok samt deltidsansat fuldtid minimum find alligevel fordeling deltidsansat alvor ryk syv strategi spil procent deltidsansat men år lønmodtagerorganisation rand del fællestillidsrepræsentant tin stenholt kast kritisk blik arbejdsforhold deltidsprocent alvor pas bedr antal kan få folk
#
# [495 rows x 12 columns]

# %% [markdown]
# Creating a new column with the three words before and after sygeplejersk is mentioned for each document

# %%
dr_analysis=find_relevant(dr_analysis, "sygeplejersk", 3)
tv2_analysis=find_relevant(tv2_analysis, "sygeplejersk", 3)
ft_analysis=find_relevant(ft_analysis, "sygeplejersk", 3)

# %% [markdown]
# ### Word frequency analysis

# %% [markdown]
# #### 1: Defining function to create a Bag of Words summed table for entire source

# %%
def BoW(df): 
    count = CountVectorizer()
    df_array = df["content_prepr"]
    bag = count.fit_transform(df_array)
    
    count_array = bag.toarray() #Make the bag to an array
    matrix = pd.DataFrame(data=count_array,columns = count.get_feature_names())
    matrix_sum = matrix.sum().transpose()
    matrix_sum.sort_values(ascending = False, inplace = True)
    return matrix_sum

# %%
def BoW_relevant(df): 
    try :
        count = CountVectorizer()
        df_array = df['relevant']
        bag = count.fit_transform(df_array)

        count_array = bag.toarray()#Make the bag to an array
        matrix = pd.DataFrame(data=count_array,columns = count.get_feature_names())
        matrix_sum = matrix.sum().transpose()
        matrix_sum.sort_values(ascending = False, inplace = True)
    except:
        pass
    return matrix_sum

# %% [markdown]
# # Overvej om der skal være et BoW exploring afsnit eller om vi skal gå direkte til wordcloud/sentiment

# %% [markdown]
# #### 2: Wordcount with relevant words

# %%
dr_bow_rel= BoW_relevant(dr_analysis)
tv2_bow_rel = BoW_relevant(tv2_analysis)
ft_bow_rel= BoW_relevant(ft_analysis)

# %% [markdown]
# Export wordcount list of relevant words to latex:

# %%
red_circle=np.array(Image.open( "red_circle.png"))

# %%
with open('dr_bow_rel.tex','w') as tf:
    tf.write(dr_bow_rel.head(100).to_latex(index=False))
with open('tv2_bow_rel.tex','w') as tf:
    tf.write(tv2_bow_rel.head(100).to_latex(index=False))
with open('ft_bow_rel.tex','w') as tf:
    tf.write(ft_bow_rel.head(100).to_latex(index=False))

# %% [markdown]
# #### 3: Creating a wordcloud of relevant words for each source

# %% [markdown]
# Importing background :

# %%
red_circle=np.array(Image.open( "red_circle.png"))

# %% [markdown]
# Plotting the wordclouds

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, sharey=False, figsize=(30,10))
_=fig.suptitle("Wordclouds for words mentioned with sygeplejerske for DR, TV2, and Folketinget", fontsize=32)
wc_dr = WordCloud(background_color="white", max_words=1000, mask=red_circle)


_=wc_dr.generate_from_frequencies(dr_bow_rel)
_=plt.subplot(1, 3, 1)
ax =plt.imshow(wc_dr, interpolation="bilinear", aspect='auto')
_=plt.axis("off")
_=plt.title("DR", fontsize=24)

_=wc_tv2 = WordCloud(background_color="white", max_words=1000, mask=red_circle)
_=wc_tv2.generate_from_frequencies(tv2_bow_rel)
_=plt.subplot(1, 3, 2)
ax =plt.imshow(wc_tv2, interpolation="bilinear", aspect='auto')
_=plt.axis("off")
_=plt.title("TV2", fontsize=24)

wc_ft = WordCloud(background_color="white", max_words=1000, mask=red_circle)
_=wc_ft.generate_from_frequencies(ft_bow_rel)
_=plt.subplot(1, 3, 3)
ax =plt.imshow(wc_ft, interpolation="bilinear", aspect='auto')
_=plt.axis("off")
_=plt.title("Folketinget", fontsize=24)

plt.savefig("wordcloud.pdf", dpi=1200)

# %% [markdown]
# #### 3: Most used words each year for each source

# %% [markdown]
# Defining function to get a bow for a year:

# %%
def top_words(df, year):
    df_year=df[df['date'].dt.year == year]
    df_year_bow=BoW_relevant(df_year)
    return df_year_bow

# %% [markdown]
# Defining function to get topwords for all years for a given df:

# %%
def top_words_table(df, num_top_words, end_year):
    top_words_list=[]
    year_list=[]
    for year in range(2012, end_year+1,1):
        top=top_words(df, year)
        top=top[:num_top_words+1]
        top_words_list.append(top.index)
        year_list.append(year)
    top_words_df=pd.DataFrame([i for i in top_words_list], year_list).transpose()
    
        
    return top_words_df

# %% [markdown]
# Creating tables of top 10 words used each year for each datafram:

# %%
tv2_top_words=top_words_table(tv2_analysis, 10, 2022)
with open('tv2_topwords.tex','w') as tf:
    tf.write(tv2_top_words.to_latex(index=False))

ft_top_words=top_words_table(ft_analysis, 10, 2022)
with open('ft_topwords.tex','w') as tf:
    tf.write(ft_top_words.to_latex(index=False))

dr_top_words=top_words_table(dr_analysis, 10, 2021)
with open('dr_topwords.tex','w') as tf:
    tf.write(dr_top_words.to_latex(index=False))

# %%
def get_title_samples(df_analysis, word, year):
    df_year = df_analysis[df_analysis['date'].dt.year == year]
    df_year = df_year[df_year['relevant'].str.contains(f"{word}")]
    return df_year

# %% [markdown]
# #### 1: Defining sentiment analysis function and appending sentiment column to df

# %%
def sentida_values(df): 
    sentida_preds = []

    for i, row in tqdm.tqdm(df.iterrows()):
        score = Sentida().sentida(row.content_cleaned, output = 'mean', normal = True)
        sentida_preds.append(score)
    
    return sentida_preds

# %%
def sentiment_column(df):
    sentida_preds = sentida_values(df)
    df['sentiment'] = sentida_preds # create new column: sentime

# %% [markdown]
# #### 2: Finding 100 words near words that contain 'sygeplejersk' to be used for FT

# %%
def extract_surround_words(text, keyword, n):
    '''
    text : input text
    keyword : the search keyword we are looking
    n : number of words around the keyword
    '''
    surround_words=[]
    #extracting all the words from text
    words = words = re.findall(r'\w+', text)
    
    #iterate through all the words
    for index, word in enumerate(words):

        #check if search keyword matches
        if keyword in word:
            #fetch left side words
            left_side_words = words[index-n : index]
            
            #fetch right side words
            right_side_words = words[index+1 : index + n + 1]
            
            surround_words.append(left_side_words)
            surround_words.append(right_side_words)
    return surround_words

# %%
def find_relevant_sen(df, word, n):
    r=[]
    for row in df["content_cleaned"]:
        temp=extract_surround_words(row, word, n)
        temp_list=[]
        for i in temp:
            stems = ' '.join(i)
            temp_list.append(stems)
        s = " ".join(temp_list)
        r.append(s)
        s = ""
    df['relevant_sen']=r
    return df

# %% [markdown]
# #### 3: Sentiment analysis on dr and tv2

# %%
sentiment_column(dr_analysis) # dr: create sentiment values and append to new sentiment column
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17548/1885380813.py in <module>
# ----> 1 sentiment_column(dr_analysis) # dr: create sentiment values and append to new sentiment column
#
# ~\AppData\Local\Temp/ipykernel_17548/1782210608.py in sentiment_column(df)
#       1 def sentiment_column(df):
# ----> 2     sentida_preds = sentida_values(df)
#       3     df['sentiment'] = sentida_preds # create new column: sentime
#
# ~\AppData\Local\Temp/ipykernel_17548/2543822861.py in sentida_values(df)
#       3
#       4     for i, row in tqdm.tqdm(df.iterrows()):
# ----> 5         score = Sentida().sentida(row.content_cleaned, output = 'mean', normal = True)
#       6         sentida_preds.append(score)
#       7
#
# NameError: name 'Sentida' is not defined

# %%
sentiment_column(tv2_analysis) # tv2: create sentiment values and append to new sentiment column

# %% [markdown]
# #### 4: Sentiment analysis of ft

# %%
ft_analysis = find_relevant_sen(ft_analysis, "sygeplej", 100) # searching for words close to 'sygeplej'

# %%
sentida_preds_ft = []

for i, row in tqdm.tqdm(ft_analysis.iterrows()):
    score = Sentida().sentida(row.relevant_sen, output = 'mean', normal = True)
    sentida_preds_ft.append(score) # create sentiment values
    
ft_analysis['sentiment'] = sentida_preds_ft # # ft: append to new sentiment column

# %%
ft_analysis['sentiment'] = sentida_preds_ft # create new column in ft_analysis df: sentiment

# %% [markdown]
# #### 5: Plot

# %%
df_sentiment = pd.concat([dr_analysis, tv2_analysis, ft_analysis], ignore_index=True) # new complete df

# %%
df_sentiment['date'] = pd.to_datetime(df_sentiment['date'], utc=True) # datetime format

# %%
fig, ax = plt.subplots(figsize=(15,7))
df_sentiment.groupby([df_sentiment.date.dt.year, 'source']).mean()['sentiment'].unstack().plot(ax=ax)

plt.suptitle("Average yearly sentiment scores of DR, TV2 and FT", size=20)
ax.set_ylabel("sentiment score")
ax.set_xlabel("date")

plt.savefig("sentiment_average_comparison.jpg")
