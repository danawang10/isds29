# %%
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from tqdm import tqdm

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Scraping

# %% [markdown]
# ## Scrape URL of articles

# %%
links = []
year_list = []

for year in range(2012, 2023, 1):
    year=f"https://search.tv2.dk/?query=sygeplejersker+{year}"
    year_list.append(year)
    
    for month in range(1,10,1): #Måned 1-9
        search_month=f"-0{month}&sort=relevance&page="
        
        for page in range(1,11,1): # (start, stop, step)
            url = year+search_month+f"{page}"
            links.append(url)
    
    for month in range(10, 13): #måned 10-12
        search_month=f"-{month}&sort=relevance&page="
        
        for page in range(1,11,1): # (start, stop, step)
            url = year+search_month+f"{page}"
            links.append(url)
len(links)

# %%
article_url=[]
for i in tqdm(links):
    try:
        resp_page = requests.get(i,headers={"Name" : "Oliver Fredborg Smietana" , "email": "ofsmietana@gmail.com"})
        soup = BeautifulSoup(resp_page.content, 'lxml')
        for link in soup.find("section").find_all('a', href=True):
            article_url.append(link['href'])
    except:
        pass
    time.sleep(0.25)
len(article_url)

# %%
df = pd.DataFrame(article_url) 
df.to_csv('article_url.csv')

# %%
df
# Out:
#                                                       0
# 0     https://nyheder.tv2.dk/2012-01-27-paa-jagt-eft...
# 1     https://nyheder.tv2.dk/business/2012-01-19-dan...
# 2     https://nyheder.tv2.dk/udland/2012-04-02-syv-e...
# 3     https://nyheder.tv2.dk/krimi/2012-03-08-42aari...
# 4     https://nyheder.tv2.dk/udland/2012-04-22-sudan...
# ...                                                 ...
# 8753  https://nyheder.tv2.dk/udland/2011-01-21-giffo...
# 8754  https://nyheder.tv2.dk/business/2015-11-04-rob...
# 8755  https://nyheder.tv2.dk/2021-01-28-dagens-overb...
# 8756  https://tvtid.tv2.dk/nytomtv/article.php/id-38...
# 8757  https://search.tv2.dk?query=sygeplejerske 2022...
#
# [8758 rows x 1 columns]

# %% [markdown]
# ## Use URL to scrape articles

# %% [markdown]
# ## Create dataframe and save it

# %% [markdown]
# # Cleaning

# %%
# read file 
tv2 = pd.read_csv('articles_tv2')

# %%
tv2 = tv2[0:100]
tv2.head(25)
# Out:
#                                          titles  \
# 0           På jagt efter danske sygeplejersker
# 1         Danske sygeplejersker får job i Norge
# 2        Syv er dræbt i amerikansk skoleskyderi
# 3            42-årig cyklist overlever påkørsel
# 4           Sudan hævder at have dræbt over 400
# 5       Opgør med fatale medicinfejl trækker ud
# 6             Hver anden har fået en fyreseddel
# 7              Dansker anholdt for vold i Norge
# 8   Domstol godkender henrettelse af retarderet
# 9       Assange vil blive på Ecuadors ambassade
# 11      Assange vil blive på Ecuadors ambassade
# 12    VIDEO: Kaster vand på politisk modstander
# 13   200.000 i protest mod spanske nedskæringer
# 14    40 pengeinstitutter forsvundet på fire år
# 15             Prinsesse Marie er gået i fødsel
# 16                  78 % risiko for SAS-konkurs
# 17         Styrtdyk i offentlige arbejdspladser
# 18   Professor: Beskæftigelsesfradrag kommer op
# 19         Huse får lov at ligge længe til salg
# 20           Politiet mangler vidner i drabssag
# 23       Tre jordemødre står prinsesse Marie bi
# 24               Finanspagt er ingen mirakelkur
# 25    Mand død efter styrt fra Fisketorvets tag
# 26      Nej til lavere erstatning til kræftsyge
# 27      Fransk præsidentbejler truer de rigeste
#
#                                            sub_header  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Syv er dræbt og tre såret ved et skoleskyderi ...
# 3                                                 NaN
# 4   Sudan påstår at have dræbt hundredvis af nabol...
# 5   Elektronisk medicinkort skal sikre, at patient...
# 6                                                 NaN
# 7                                                 NaN
# 8   Dødsdømt mentalt retarderet fange i Texas slip...
# 9   WikiLeaks-stifteren angriber Sverige og Austra...
# 11  WikiLeaks-stifteren angriber Sverige og Austra...
# 12                                                NaN
# 13  Omkring 200.000 spaniere var torsdag på gaden ...
# 14  Siden 2008 er 40 pengeinstitutter forsvundet e...
# 15                                                NaN
# 16                                                NaN
# 17  Især inden for ældrepleje, børnepasning og sko...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  Patientforsikringen har igennem flere år nedsa...
# 27  Den franske præsidentkandidat François Holland...
#
#                                                    h2  \
# 0   ['Dansk sygeplejeråd: "What a waste"', 'Flere ...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5                                                  []
# 6   ['Fyringer giver et dynamisk arbejdsmarked', '...
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15  ['Rutineret fødselsteam ved Maries side', 'Reg...
# 16                        ['Usikkerhed om fremtiden']
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20  ['Tvivler ikke på, at der er vidner', 'Overfal...
# 23                                                 []
# 24                           ['Sundere på lang sigt']
# 25                                                 []
# 26                                                 []
# 27                                                 []
#
#                                               content  \
# 0   Mens nyuddannede, danske sygeplejersker har me...
# 1   Antallet af danske sygeplejersker, der har fåe...
# 2   En bevæbnet mand har skudt og dræbt syv person...
# 3   Læger kæmpede natten til torsdag for at redde ...
# 4   Sudanske tropper har de seneste dage dræbt ove...
# 5   Hvert år dør hundredvis af patienter, fordi su...
# 6   Mere end hver anden har i løbet af deres voksn...
# 7   En dansk mand er blevet anholdt, efter en 31-å...
# 8   I USA har Højesteret banet vejen for henrettel...
# 9   Den omdiskuterede stifter af WikiLeaks, Julian...
# 11  Den omdiskuterede stifter af WikiLeaks, Julian...
# 12  Det er ikke helt klart, hvad der var dråben, d...
# 13  Sygeplejersker, lærere, politifolk og unge akt...
# 14  Det viser en opgørelse, som Nyhedsbrevet Finan...
# 15  Prinsesse Marie er blevet indlagt på Rigshospi...
# 16  Det er rekorddyrt at forsikre virksomhedsoblig...
# 17  Antallet af hjemmehjælpere, pædagoger, lærere ...
# 18  Når regeringen vil sænke skatten på arbejde ud...
# 19  I hver femte kommune overstiger den gennemsnit...
# 20  Politiet har fået kontakt til to vidner, der h...
# 23  Prinsesse Marie er i gode hænder under fødslen...
# 24  Der er stadig lang vej for at løse de økonomis...
# 25  En 20-årig mand styrtede tirsdag aften ned fra...
# 26  Patientforsikringen forsøgte for godt ti år si...
# 27  Det bliver dyrt for Frankrigs rigeste, hvis so...
#
#                              author       tag                      date  \
# 0     Natali Braagaard, nabr@tv2.dk   Nyheder  2012-01-27T04:57:00.000Z
# 1                       Ritzau/meng  Business  2012-01-19T12:38:23.000Z
# 2                            ritzau    Udland  2012-04-02T23:31:00.000Z
# 3                     ritzau / ptho     Krimi  2012-03-08T00:25:00.000Z
# 4                            ritzau    Udland  2012-04-22T23:51:02.000Z
# 5                            ritzau   Nyheder  2012-12-07T00:44:02.000Z
# 6                     ritzau / mira   Nyheder  2012-02-25T00:35:00.000Z
# 7      Maria Bundgaard, marb@tv2.dk     Krimi  2012-01-10T06:48:00.000Z
# 8                            ritzau    Udland  2012-08-07T23:42:01.000Z
# 9                            ritzau    Udland  2012-06-21T23:48:02.000Z
# 11                           ritzau    Udland  2012-06-21T23:48:02.000Z
# 12          David Buch, dabu@tv2.dk    Udland  2012-01-10T10:40:00.000Z
# 13                           ritzau    Udland  2012-01-27T02:26:12.000Z
# 14                           ritzau  Business  2012-01-10T11:49:00.000Z
# 15  Kristian Hedegaard, kris@tv2.dk   Nyheder  2012-01-24T06:48:00.000Z
# 16                      bjah@tv2.dk  Business  2012-01-17T11:52:00.000Z
# 17                           ritzau   Nyheder  2012-01-17T02:36:02.000Z
# 18                    ritzau / ptho   Nyheder  2012-01-18T10:31:00.000Z
# 19                    ritzau / jely   Nyheder  2012-01-31T11:59:00.000Z
# 20                    ritzau / jely     Krimi  2012-01-22T11:41:00.000Z
# 23  Kristian Hedegaard, kris@tv2.dk   Nyheder  2012-01-24T08:02:00.000Z
# 24                    ritzau / ansc  Business  2012-01-30T23:21:00.000Z
# 25                    ritzau / krja     Krimi  2012-06-26T23:03:00.000Z
# 26                           ritzau   Nyheder  2012-01-29T00:16:00.000Z
# 27                           ritzau    Udland  2012-02-28T00:15:02.000Z
#
#                                                  link  tv2
# 0   https://nyheder.tv2.dk/2012-01-27-paa-jagt-eft...  tv2
# 1   https://nyheder.tv2.dk/business/2012-01-19-dan...  tv2
# 2   https://nyheder.tv2.dk/udland/2012-04-02-syv-e...  tv2
# 3   https://nyheder.tv2.dk/krimi/2012-03-08-42aari...  tv2
# 4   https://nyheder.tv2.dk/udland/2012-04-22-sudan...  tv2
# 5   https://nyheder.tv2.dk/2012-12-07-opgoer-med-f...  tv2
# 6   https://nyheder.tv2.dk/2012-02-25-hver-anden-h...  tv2
# 7   https://nyheder.tv2.dk/krimi/2012-01-10-danske...  tv2
# 8   https://nyheder.tv2.dk/udland/2012-08-07-domst...  tv2
# 9   https://nyheder.tv2.dk/udland/2012-06-21-assan...  tv2
# 11  https://nyheder.tv2.dk/udland/2012-06-21-assan...  tv2
# 12  https://nyheder.tv2.dk/udland/2012-01-10-video...  tv2
# 13  https://nyheder.tv2.dk/udland/2012-01-27-20000...  tv2
# 14  https://nyheder.tv2.dk/business/2012-01-10-40-...  tv2
# 15  https://nyheder.tv2.dk/2012-01-24-prinsesse-ma...  tv2
# 16  https://nyheder.tv2.dk/business/2012-01-17-78-...  tv2
# 17  https://nyheder.tv2.dk/2012-01-17-styrtdyk-i-o...  tv2
# 18  https://nyheder.tv2.dk/2012-01-18-professor-be...  tv2
# 19  https://nyheder.tv2.dk/2012-01-31-huse-faar-lo...  tv2
# 20  https://nyheder.tv2.dk/krimi/2012-01-22-politi...  tv2
# 23  https://nyheder.tv2.dk/2012-01-24-tre-jordemoe...  tv2
# 24  https://nyheder.tv2.dk/business/2012-01-30-fin...  tv2
# 25  https://nyheder.tv2.dk/article.php/id-51398701...  tv2
# 26  https://nyheder.tv2.dk/article.php/id-47796227...  tv2
# 27  https://nyheder.tv2.dk/article.php/id-48517447...  tv2

# %%
# Remove 'back' and 'next' rows 
tv2 = tv2[tv2.titles != 'Søg på TV 2']

# %%
tv2

# %%
# pd.set_option('max_colwidth', 50)

# %% [markdown]
# # Descriptive statistics

# %%
plt.style.use('ggplot')

fig, ax = plt.subplots(nrows = 1, ncols = 1) # create placeholder for plot
ax = sns.countplot(x = 'tag', data = tv2)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-9fd0eb0d757d> in <module>
# ----> 1 tv2.groupby([tv2.index.tag, 'tag']).count()
#
# AttributeError: 'Int64Index' object has no attribute 'tag'
